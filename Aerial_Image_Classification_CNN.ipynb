# %% [markdown]
# <a href="https://colab.research.google.com/github/OConnorsphysics/Data_Science_Machine_Learning/blob/main/Liams_Project2_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color= 'lightblue'>**Identifying Location Class from Aerial Imagery** </font>

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1Fo2x1i7BvwMI2vPrQoQyl2Ks6mhcC1ta)

# %% [markdown]
# In this notebook we will be building varying neural networks to predict ground structures and vegetation using aerial imagery. Aerial scene classification is a large field of study within remote sensing, which requires large, diverse datasets. As more high quality satelitte imagery becomes publicly accesible there is a drive to build accurate models to predict, sort, and map ground targets. The ultimate question this leads to is:
#
# **Given any sattelite image, regardless of season, or time of day, can we use a neural network to accurately predict what we have imaged?**
#
# The dataset we will use in our model was compiled by Gui-Song Xia, Jingwen Hu, Fan Hu, Baoguang Shi, Xiang Bai, Yanfei Zhong, and Liangpei Zhang. These researchers co-authored a paper titled "AID: A Benchmark Dataset for Performance Evaluation of Aerial Scene Classification". The data set consists of 10 000 RGB images, that fall into 30 labelled classifications. The images are gathered from Google earth imagery, which uses multiple sensors for collection. The data set has high intra-class diversity as images were taken during different seasons, times of the day, and under varying lighting conditions. The majority of the photos are from China, the United States, England, France, Italy, Japan, Germany.
#
# We will build both a dense and convolutional neural network in hopes of accurately classifying the scenes. To compare the different models we will train them both on the same 80% of the dataset. We will withhold 20% for testing and validation of the models.

# %%
#load required packages
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ###<font color= 'lightblue'>**Importing Data & Preprocessing** </font>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/MyDrive/AerialImageDataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: AID/Mountain/mountain_300.jpg
#   inflating: AID/Mountain/mountain_301.jpg
#   inflating: AID/Mountain/mountain_302.jpg
#   inflating: AID/Mountain/mountain_303.jpg
#   inflating: AID/Mountain/mountain_304.jpg
#   inflating: AID/Mountain/mountain_305.jpg
#   inflating: AID/Mountain/mountain_306.jpg
#   inflating: AID/Mountain/mountain_307.jpg
#   inflating: AID/Mountain/mountain_308.jpg
#   inflating: AID/Mountain/mountain_309.jpg
#   inflating: AID/Mountain/mountain_31.jpg
#   inflating: AID/Mountain/mountain_310.jpg
#   inflating: AID/Mountain/mountain_311.jpg
#   inflating: AID/Mountain/mountain_312.jpg
#   inflating: AID/Mountain/mountain_313.jpg
#   inflating: AID/Mountain/mountain_314.jpg
#   inflating: AID/Mountain/mountain_315.jpg
#   inflating: AID/Mountain/mountain_316.jpg
#   inflating: AID/Mountain/mountain_317.jpg
#   inflating: AID/Mountain/mountain_318.jpg
#   inflating: AID/Mountain/mountain_319.jpg
#   inflating: AID/Mountain/mountain_32.jpg
#   inflating: AID/Mountain/mountain_320.jpg
#   inflating: AID/Mountain/mountain_321.jpg
#   inflating: AID/Mountain/mountain_322.jpg
#   inflating: AID/Mountain/mountain_323.jpg
#   inflating: AID/Mountain/mountain_324.jpg
#   inflating: AID/Mountain/mountain_325.jpg
#   inflating: AID/Mountain/mountain_326.jpg
#   inflating: AID/Mountain/mountain_327.jpg
#   inflating: AID/Mountain/mountain_328.jpg
#   inflating: AID/Mountain/mountain_329.jpg
#   inflating: AID/Mountain/mountain_33.jpg
#   inflating: AID/Mountain/mountain_330.jpg
#   inflating: AID/Mountain/mountain_331.jpg
#   inflating: AID/Mountain/mountain_332.jpg
#   inflating: AID/Mountain/mountain_333.jpg
#   inflating: AID/Mountain/mountain_334.jpg
#   inflating: AID/Mountain/mountain_335.jpg
#   inflating: AID/Mountain/mountain_336.jpg
#   inflating: AID/Mountain/mountain_337.jpg
#   inflating: AID/Mountain/mountain_338.jpg
#   inflating: AID/Mountain/mountain_339.jpg
#   inflating: AID/Mountain/mountain_34.jpg
#   inflating: AID/Mountain/mountain_340.jpg
#   inflating: AID/Mountain/mountain_35.jpg
#   inflating: AID/Mountain/mountain_36.jpg
#   inflating: AID/Mountain/mountain_37.jpg
#   inflating: AID/Mountain/mountain_38.jpg
#   inflating: AID/Mountain/mountain_39.jpg
#   inflating: AID/Mountain/mountain_4.jpg
#   inflating: AID/Mountain/mountain_40.jpg
#   inflating: AID/Mountain/mountain_41.jpg
#   inflating: AID/Mountain/mountain_42.jpg
#   inflating: AID/Mountain/mountain_43.jpg
#   inflating: AID/Mountain/mountain_44.jpg
#   inflating: AID/Mountain/mountain_45.jpg
#   inflating: AID/Mountain/mountain_46.jpg
#   inflating: AID/Mountain/mountain_47.jpg
#   inflating: AID/Mountain/mountain_48.jpg
#   inflating: AID/Mountain/mountain_49.jpg
#   inflating: AID/Mountain/mountain_5.jpg
#   inflating: AID/Mountain/mountain_50.jpg
#   inflating: AID/Mountain/mountain_51.jpg
#   inflating: AID/Mountain/mountain_52.jpg
#   inflating: AID/Mountain/mountain_53.jpg
#   inflating: AID/Mountain/mountain_54.jpg
#   inflating: AID/Mountain/mountain_55.jpg
#   inflating: AID/Mountain/mountain_56.jpg
#   inflating: AID/Mountain/mountain_57.jpg
#   inflating: AID/Mountain/mountain_58.jpg
#   inflating: AID/Mountain/mountain_59.jpg
#   inflating: AID/Mountain/mountain_6.jpg
#   inflating: AID/Mountain/mountain_60.jpg
#   inflating: AID/Mountain/mountain_61.jpg
#   inflating: AID/Mountain/mountain_62.jpg
#   inflating: AID/Mountain/mountain_63.jpg
#   inflating: AID/Mountain/mountain_64.jpg
#   inflating: AID/Mountain/mountain_65.jpg
#   inflating: AID/Mountain/mountain_66.jpg
#   inflating: AID/Mountain/mountain_67.jpg
#   inflating: AID/Mountain/mountain_68.jpg
#   inflating: AID/Mountain/mountain_69.jpg
#   inflating: AID/Mountain/mountain_7.jpg
#   inflating: AID/Mountain/mountain_70.jpg
#   inflating: AID/Mountain/mountain_71.jpg
#   inflating: AID/Mountain/mountain_72.jpg
#   inflating: AID/Mountain/mountain_73.jpg
#   inflating: AID/Mountain/mountain_74.jpg
#   inflating: AID/Mountain/mountain_75.jpg
#   inflating: AID/Mountain/mountain_76.jpg
#   inflating: AID/Mountain/mountain_77.jpg
#   inflating: AID/Mountain/mountain_78.jpg
#   inflating: AID/Mountain/mountain_79.jpg
#   inflating: AID/Mountain/mountain_8.jpg
#   inflating: AID/Mountain/mountain_80.jpg
#   inflating: AID/Mountain/mountain_81.jpg
#   inflating: AID/Mountain/mountain_82.jpg
#   inflating: AID/Mountain/mountain_83.jpg
#   inflating: AID/Mountain/mountain_84.jpg
#   inflating: AID/Mountain/mountain_85.jpg
#   inflating: AID/Mountain/mountain_86.jpg
#   inflating: AID/Mountain/mountain_87.jpg
#   inflating: AID/Mountain/mountain_88.jpg
#   inflating: AID/Mountain/mountain_89.jpg
#   inflating: AID/Mountain/mountain_9.jpg
#   inflating: AID/Mountain/mountain_90.jpg
#   inflating: AID/Mountain/mountain_91.jpg
#   inflating: AID/Mountain/mountain_92.jpg
#   inflating: AID/Mountain/mountain_93.jpg
#   inflating: AID/Mountain/mountain_94.jpg
#   inflating: AID/Mountain/mountain_95.jpg
#   inflating: AID/Mountain/mountain_96.jpg
#   inflating: AID/Mountain/mountain_97.jpg
#   inflating: AID/Mountain/mountain_98.jpg
#   inflating: AID/Mountain/mountain_99.jpg
#    creating: AID/Park/
#   inflating: AID/Park/park_1.jpg
#   inflating: AID/Park/park_10.jpg
#   inflating: AID/Park/park_100.jpg
#   inflating: AID/Park/park_101.jpg
#   inflating: AID/Park/park_102.jpg
#   inflating: AID/Park/park_103.jpg
#   inflating: AID/Park/park_104.jpg
#   inflating: AID/Park/park_105.jpg
#   inflating: AID/Park/park_106.jpg
#   inflating: AID/Park/park_107.jpg
#   inflating: AID/Park/park_108.jpg
#   inflating: AID/Park/park_109.jpg
#   inflating: AID/Park/park_11.jpg
#   inflating: AID/Park/park_110.jpg
#   inflating: AID/Park/park_111.jpg
#   inflating: AID/Park/park_112.jpg
#   inflating: AID/Park/park_113.jpg
#   inflating: AID/Park/park_114.jpg
#   inflating: AID/Park/park_115.jpg
#   inflating: AID/Park/park_116.jpg
#   inflating: AID/Park/park_117.jpg
#   inflating: AID/Park/park_118.jpg
#   inflating: AID/Park/park_119.jpg
#   inflating: AID/Park/park_12.jpg
#   inflating: AID/Park/park_120.jpg
#   inflating: AID/Park/park_121.jpg
#   inflating: AID/Park/park_122.jpg
#   inflating: AID/Park/park_123.jpg
#   inflating: AID/Park/park_124.jpg
#   inflating: AID/Park/park_125.jpg
#   inflating: AID/Park/park_126.jpg
#   inflating: AID/Park/park_127.jpg
#   inflating: AID/Park/park_128.jpg
#   inflating: AID/Park/park_129.jpg
#   inflating: AID/Park/park_13.jpg
#   inflating: AID/Park/park_130.jpg
#   inflating: AID/Park/park_131.jpg
#   inflating: AID/Park/park_132.jpg
#   inflating: AID/Park/park_133.jpg
#   inflating: AID/Park/park_134.jpg
#   inflating: AID/Park/park_135.jpg
#   inflating: AID/Park/park_136.jpg
#   inflating: AID/Park/park_137.jpg
#   inflating: AID/Park/park_138.jpg
#   inflating: AID/Park/park_139.jpg
#   inflating: AID/Park/park_14.jpg
#   inflating: AID/Park/park_140.jpg
#   inflating: AID/Park/park_141.jpg
#   inflating: AID/Park/park_142.jpg
#   inflating: AID/Park/park_143.jpg
#   inflating: AID/Park/park_144.jpg
#   inflating: AID/Park/park_145.jpg
#   inflating: AID/Park/park_146.jpg
#   inflating: AID/Park/park_147.jpg
#   inflating: AID/Park/park_148.jpg
#   inflating: AID/Park/park_149.jpg
#   inflating: AID/Park/park_15.jpg
#   inflating: AID/Park/park_150.jpg
#   inflating: AID/Park/park_151.jpg
#   inflating: AID/Park/park_152.jpg
#   inflating: AID/Park/park_153.jpg
#   inflating: AID/Park/park_154.jpg
#   inflating: AID/Park/park_155.jpg
#   inflating: AID/Park/park_156.jpg
#   inflating: AID/Park/park_157.jpg
#   inflating: AID/Park/park_158.jpg
#   inflating: AID/Park/park_159.jpg
#   inflating: AID/Park/park_16.jpg
#   inflating: AID/Park/park_160.jpg
#   inflating: AID/Park/park_161.jpg
#   inflating: AID/Park/park_162.jpg
#   inflating: AID/Park/park_163.jpg
#   inflating: AID/Park/park_164.jpg
#   inflating: AID/Park/park_165.jpg
#   inflating: AID/Park/park_166.jpg
#   inflating: AID/Park/park_167.jpg
#   inflating: AID/Park/park_168.jpg
#   inflating: AID/Park/park_169.jpg
#   inflating: AID/Park/park_17.jpg
#   inflating: AID/Park/park_170.jpg
#   inflating: AID/Park/park_171.jpg
#   inflating: AID/Park/park_172.jpg
#   inflating: AID/Park/park_173.jpg
#   inflating: AID/Park/park_174.jpg
#   inflating: AID/Park/park_175.jpg
#   inflating: AID/Park/park_176.jpg
#   inflating: AID/Park/park_177.jpg
#   inflating: AID/Park/park_178.jpg
#   inflating: AID/Park/park_179.jpg
#   inflating: AID/Park/park_18.jpg
#   inflating: AID/Park/park_180.jpg
#   inflating: AID/Park/park_181.jpg
#   inflating: AID/Park/park_182.jpg
#   inflating: AID/Park/park_183.jpg
#   inflating: AID/Park/park_184.jpg
#   inflating: AID/Park/park_185.jpg
#   inflating: AID/Park/park_186.jpg
#   inflating: AID/Park/park_187.jpg
#   inflating: AID/Park/park_188.jpg
#   inflating: AID/Park/park_189.jpg
#   inflating: AID/Park/park_19.jpg
#   inflating: AID/Park/park_190.jpg
#   inflating: AID/Park/park_191.jpg
#   inflating: AID/Park/park_192.jpg
#   inflating: AID/Park/park_193.jpg
#   inflating: AID/Park/park_194.jpg
#   inflating: AID/Park/park_195.jpg
#   inflating: AID/Park/park_196.jpg
#   inflating: AID/Park/park_197.jpg
#   inflating: AID/Park/park_198.jpg
#   inflating: AID/Park/park_199.jpg
#   inflating: AID/Park/park_2.jpg
#   inflating: AID/Park/park_20.jpg
#   inflating: AID/Park/park_200.jpg
#   inflating: AID/Park/park_201.jpg
#   inflating: AID/Park/park_202.jpg
#   inflating: AID/Park/park_203.jpg
#   inflating: AID/Park/park_204.jpg
#   inflating: AID/Park/park_205.jpg
#   inflating: AID/Park/park_206.jpg
#   inflating: AID/Park/park_207.jpg
#   inflating: AID/Park/park_208.jpg
#   inflating: AID/Park/park_209.jpg
#   inflating: AID/Park/park_21.jpg
#   inflating: AID/Park/park_210.jpg
#   inflating: AID/Park/park_211.jpg
#   inflating: AID/Park/park_212.jpg
#   inflating: AID/Park/park_213.jpg
#   inflating: AID/Park/park_214.jpg
#   inflating: AID/Park/park_215.jpg
#   inflating: AID/Park/park_216.jpg
#   inflating: AID/Park/park_217.jpg
#   inflating: AID/Park/park_218.jpg
#   inflating: AID/Park/park_219.jpg
#   inflating: AID/Park/park_22.jpg
#   inflating: AID/Park/park_220.jpg
#   inflating: AID/Park/park_221.jpg
#   inflating: AID/Park/park_222.jpg
#   inflating: AID/Park/park_223.jpg
#   inflating: AID/Park/park_224.jpg
#   inflating: AID/Park/park_225.jpg
#   inflating: AID/Park/park_226.jpg
#   inflating: AID/Park/park_227.jpg
#   inflating: AID/Park/park_228.jpg
#   inflating: AID/Park/park_229.jpg
#   inflating: AID/Park/park_23.jpg
#   inflating: AID/Park/park_230.jpg
#   inflating: AID/Park/park_231.jpg
#   inflating: AID/Park/park_232.jpg
#   inflating: AID/Park/park_233.jpg
#   inflating: AID/Park/park_234.jpg
#   inflating: AID/Park/park_235.jpg
#   inflating: AID/Park/park_236.jpg
#   inflating: AID/Park/park_237.jpg
#   inflating: AID/Park/park_238.jpg
#   inflating: AID/Park/park_239.jpg
#   inflating: AID/Park/park_24.jpg
#   inflating: AID/Park/park_240.jpg
#   inflating: AID/Park/park_241.jpg
#   inflating: AID/Park/park_242.jpg
#   inflating: AID/Park/park_243.jpg
#   inflating: AID/Park/park_244.jpg
#   inflating: AID/Park/park_245.jpg
#   inflating: AID/Park/park_246.jpg
#   inflating: AID/Park/park_247.jpg
#   inflating: AID/Park/park_248.jpg
#   inflating: AID/Park/park_249.jpg
#   inflating: AID/Park/park_25.jpg
#   inflating: AID/Park/park_250.jpg
#   inflating: AID/Park/park_251.jpg
#   inflating: AID/Park/park_252.jpg
#   inflating: AID/Park/park_253.jpg
#   inflating: AID/Park/park_254.jpg
#   inflating: AID/Park/park_255.jpg
#   inflating: AID/Park/park_256.jpg
#   inflating: AID/Park/park_257.jpg
#   inflating: AID/Park/park_258.jpg
#   inflating: AID/Park/park_259.jpg
#   inflating: AID/Park/park_26.jpg
#   inflating: AID/Park/park_260.jpg
#   inflating: AID/Park/park_261.jpg
#   inflating: AID/Park/park_262.jpg
#   inflating: AID/Park/park_263.jpg
#   inflating: AID/Park/park_264.jpg
#   inflating: AID/Park/park_265.jpg
#   inflating: AID/Park/park_266.jpg
#   inflating: AID/Park/park_267.jpg
#   inflating: AID/Park/park_268.jpg
#   inflating: AID/Park/park_269.jpg
#   inflating: AID/Park/park_27.jpg
#   inflating: AID/Park/park_270.jpg
#   inflating: AID/Park/park_271.jpg
#   inflating: AID/Park/park_272.jpg
#   inflating: AID/Park/park_273.jpg
#   inflating: AID/Park/park_274.jpg
#   inflating: AID/Park/park_275.jpg
#   inflating: AID/Park/park_276.jpg
#   inflating: AID/Park/park_277.jpg
#   inflating: AID/Park/park_278.jpg
#   inflating: AID/Park/park_279.jpg
#   inflating: AID/Park/park_28.jpg
#   inflating: AID/Park/park_280.jpg
#   inflating: AID/Park/park_281.jpg
#   inflating: AID/Park/park_282.jpg
#   inflating: AID/Park/park_283.jpg
#   inflating: AID/Park/park_284.jpg
#   inflating: AID/Park/park_285.jpg
#   inflating: AID/Park/park_286.jpg
#   inflating: AID/Park/park_287.jpg
#   inflating: AID/Park/park_288.jpg
#   inflating: AID/Park/park_289.jpg
#   inflating: AID/Park/park_29.jpg
#   inflating: AID/Park/park_290.jpg
#   inflating: AID/Park/park_291.jpg
#   inflating: AID/Park/park_292.jpg
#   inflating: AID/Park/park_293.jpg
#   inflating: AID/Park/park_294.jpg
#   inflating: AID/Park/park_295.jpg
#   inflating: AID/Park/park_296.jpg
#   inflating: AID/Park/park_297.jpg
#   inflating: AID/Park/park_298.jpg
#   inflating: AID/Park/park_299.jpg
#   inflating: AID/Park/park_3.jpg
#   inflating: AID/Park/park_30.jpg
#   inflating: AID/Park/park_300.jpg
#   inflating: AID/Park/park_301.jpg
#   inflating: AID/Park/park_302.jpg
#   inflating: AID/Park/park_303.jpg
#   inflating: AID/Park/park_304.jpg
#   inflating: AID/Park/park_305.jpg
#   inflating: AID/Park/park_306.jpg
#   inflating: AID/Park/park_307.jpg
#   inflating: AID/Park/park_308.jpg
#   inflating: AID/Park/park_309.jpg
#   inflating: AID/Park/park_31.jpg
#   inflating: AID/Park/park_310.jpg
#   inflating: AID/Park/park_311.jpg
#   inflating: AID/Park/park_312.jpg
#   inflating: AID/Park/park_313.jpg
#   inflating: AID/Park/park_314.jpg
#   inflating: AID/Park/park_315.jpg
#   inflating: AID/Park/park_316.jpg
#   inflating: AID/Park/park_317.jpg
#   inflating: AID/Park/park_318.jpg
#   inflating: AID/Park/park_319.jpg
#   inflating: AID/Park/park_32.jpg
#   inflating: AID/Park/park_320.jpg
#   inflating: AID/Park/park_321.jpg
#   inflating: AID/Park/park_322.jpg
#   inflating: AID/Park/park_323.jpg
#   inflating: AID/Park/park_324.jpg
#   inflating: AID/Park/park_325.jpg
#   inflating: AID/Park/park_326.jpg
#   inflating: AID/Park/park_327.jpg
#   inflating: AID/Park/park_328.jpg
#   inflating: AID/Park/park_329.jpg
#   inflating: AID/Park/park_33.jpg
#   inflating: AID/Park/park_330.jpg
#   inflating: AID/Park/park_331.jpg
#   inflating: AID/Park/park_332.jpg
#   inflating: AID/Park/park_333.jpg
#   inflating: AID/Park/park_334.jpg
#   inflating: AID/Park/park_335.jpg
#   inflating: AID/Park/park_336.jpg
#   inflating: AID/Park/park_337.jpg
#   inflating: AID/Park/park_338.jpg
#   inflating: AID/Park/park_339.jpg
#   inflating: AID/Park/park_34.jpg
#   inflating: AID/Park/park_340.jpg
#   inflating: AID/Park/park_341.jpg
#   inflating: AID/Park/park_342.jpg
#   inflating: AID/Park/park_343.jpg
#   inflating: AID/Park/park_344.jpg
#   inflating: AID/Park/park_345.jpg
#   inflating: AID/Park/park_346.jpg
#   inflating: AID/Park/park_347.jpg
#   inflating: AID/Park/park_348.jpg
#   inflating: AID/Park/park_349.jpg
#   inflating: AID/Park/park_35.jpg
#   inflating: AID/Park/park_350.jpg
#   inflating: AID/Park/park_36.jpg
#   inflating: AID/Park/park_37.jpg
#   inflating: AID/Park/park_38.jpg
#   inflating: AID/Park/park_39.jpg
#   inflating: AID/Park/park_4.jpg
#   inflating: AID/Park/park_40.jpg
#   inflating: AID/Park/park_41.jpg
#   inflating: AID/Park/park_42.jpg
#   inflating: AID/Park/park_43.jpg
#   inflating: AID/Park/park_44.jpg
#   inflating: AID/Park/park_45.jpg
#   inflating: AID/Park/park_46.jpg
#   inflating: AID/Park/park_47.jpg
#   inflating: AID/Park/park_48.jpg
#   inflating: AID/Park/park_49.jpg
#   inflating: AID/Park/park_5.jpg
#   inflating: AID/Park/park_50.jpg
#   inflating: AID/Park/park_51.jpg
#   inflating: AID/Park/park_52.jpg
#   inflating: AID/Park/park_53.jpg
#   inflating: AID/Park/park_54.jpg
#   inflating: AID/Park/park_55.jpg
#   inflating: AID/Park/park_56.jpg
#   inflating: AID/Park/park_57.jpg
#   inflating: AID/Park/park_58.jpg
#   inflating: AID/Park/park_59.jpg
#   inflating: AID/Park/park_6.jpg
#   inflating: AID/Park/park_60.jpg
#   inflating: AID/Park/park_61.jpg
#   inflating: AID/Park/park_62.jpg
#   inflating: AID/Park/park_63.jpg
#   inflating: AID/Park/park_64.jpg
#   inflating: AID/Park/park_65.jpg
#   inflating: AID/Park/park_66.jpg
#   inflating: AID/Park/park_67.jpg
#   inflating: AID/Park/park_68.jpg
#   inflating: AID/Park/park_69.jpg
#   inflating: AID/Park/park_7.jpg
#   inflating: AID/Park/park_70.jpg
#   inflating: AID/Park/park_71.jpg
#   inflating: AID/Park/park_72.jpg
#   inflating: AID/Park/park_73.jpg
#   inflating: AID/Park/park_74.jpg
#   inflating: AID/Park/park_75.jpg
#   inflating: AID/Park/park_76.jpg
#   inflating: AID/Park/park_77.jpg
#   inflating: AID/Park/park_78.jpg
#   inflating: AID/Park/park_79.jpg
#   inflating: AID/Park/park_8.jpg
#   inflating: AID/Park/park_80.jpg
#   inflating: AID/Park/park_81.jpg
#   inflating: AID/Park/park_82.jpg
#   inflating: AID/Park/park_83.jpg
#   inflating: AID/Park/park_84.jpg
#   inflating: AID/Park/park_85.jpg
#   inflating: AID/Park/park_86.jpg
#   inflating: AID/Park/park_87.jpg
#   inflating: AID/Park/park_88.jpg
#   inflating: AID/Park/park_89.jpg
#   inflating: AID/Park/park_9.jpg
#   inflating: AID/Park/park_90.jpg
#   inflating: AID/Park/park_91.jpg
#   inflating: AID/Park/park_92.jpg
#   inflating: AID/Park/park_93.jpg
#   inflating: AID/Park/park_94.jpg
#   inflating: AID/Park/park_95.jpg
#   inflating: AID/Park/park_96.jpg
#   inflating: AID/Park/park_97.jpg
#   inflating: AID/Park/park_98.jpg
#   inflating: AID/Park/park_99.jpg
#    creating: AID/Parking/
#   inflating: AID/Parking/parking_1.jpg
#   inflating: AID/Parking/parking_10.jpg
#   inflating: AID/Parking/parking_100.jpg
#   inflating: AID/Parking/parking_101.jpg
#   inflating: AID/Parking/parking_102.jpg
#   inflating: AID/Parking/parking_103.jpg
#   inflating: AID/Parking/parking_104.jpg
#   inflating: AID/Parking/parking_105.jpg
#   inflating: AID/Parking/parking_106.jpg
#   inflating: AID/Parking/parking_107.jpg
#   inflating: AID/Parking/parking_108.jpg
#   inflating: AID/Parking/parking_109.jpg
#   inflating: AID/Parking/parking_11.jpg
#   inflating: AID/Parking/parking_110.jpg
#   inflating: AID/Parking/parking_111.jpg
#   inflating: AID/Parking/parking_112.jpg
#   inflating: AID/Parking/parking_113.jpg
#   inflating: AID/Parking/parking_114.jpg
#   inflating: AID/Parking/parking_115.jpg
#   inflating: AID/Parking/parking_116.jpg
#   inflating: AID/Parking/parking_117.jpg
#   inflating: AID/Parking/parking_118.jpg
#   inflating: AID/Parking/parking_119.jpg
#   inflating: AID/Parking/parking_12.jpg
#   inflating: AID/Parking/parking_120.jpg
#   inflating: AID/Parking/parking_121.jpg
#   inflating: AID/Parking/parking_122.jpg
#   inflating: AID/Parking/parking_123.jpg
#   inflating: AID/Parking/parking_124.jpg
#   inflating: AID/Parking/parking_125.jpg
#   inflating: AID/Parking/parking_126.jpg
#   inflating: AID/Parking/parking_127.jpg
#   inflating: AID/Parking/parking_128.jpg
#   inflating: AID/Parking/parking_129.jpg
#   inflating: AID/Parking/parking_13.jpg
#   inflating: AID/Parking/parking_130.jpg
#   inflating: AID/Parking/parking_131.jpg
#   inflating: AID/Parking/parking_132.jpg
#   inflating: AID/Parking/parking_133.jpg
#   inflating: AID/Parking/parking_134.jpg
#   inflating: AID/Parking/parking_135.jpg
#   inflating: AID/Parking/parking_136.jpg
#   inflating: AID/Parking/parking_137.jpg
#   inflating: AID/Parking/parking_138.jpg
#   inflating: AID/Parking/parking_139.jpg
#   inflating: AID/Parking/parking_14.jpg
#   inflating: AID/Parking/parking_140.jpg
#   inflating: AID/Parking/parking_141.jpg
#   inflating: AID/Parking/parking_142.jpg
#   inflating: AID/Parking/parking_143.jpg
#   inflating: AID/Parking/parking_144.jpg
#   inflating: AID/Parking/parking_145.jpg
#   inflating: AID/Parking/parking_146.jpg
#   inflating: AID/Parking/parking_147.jpg
#   inflating: AID/Parking/parking_148.jpg
#   inflating: AID/Parking/parking_149.jpg
#   inflating: AID/Parking/parking_15.jpg
#   inflating: AID/Parking/parking_150.jpg
#   inflating: AID/Parking/parking_151.jpg
#   inflating: AID/Parking/parking_152.jpg
#   inflating: AID/Parking/parking_153.jpg
#   inflating: AID/Parking/parking_154.jpg
#   inflating: AID/Parking/parking_155.jpg
#   inflating: AID/Parking/parking_156.jpg
#   inflating: AID/Parking/parking_157.jpg
#   inflating: AID/Parking/parking_158.jpg
#   inflating: AID/Parking/parking_159.jpg
#   inflating: AID/Parking/parking_16.jpg
#   inflating: AID/Parking/parking_160.jpg
#   inflating: AID/Parking/parking_161.jpg
#   inflating: AID/Parking/parking_162.jpg
#   inflating: AID/Parking/parking_163.jpg
#   inflating: AID/Parking/parking_164.jpg
#   inflating: AID/Parking/parking_165.jpg
#   inflating: AID/Parking/parking_166.jpg
#   inflating: AID/Parking/parking_167.jpg
#   inflating: AID/Parking/parking_168.jpg
#   inflating: AID/Parking/parking_169.jpg
#   inflating: AID/Parking/parking_17.jpg
#   inflating: AID/Parking/parking_170.jpg
#   inflating: AID/Parking/parking_171.jpg
#   inflating: AID/Parking/parking_172.jpg
#   inflating: AID/Parking/parking_173.jpg
#   inflating: AID/Parking/parking_174.jpg
#   inflating: AID/Parking/parking_175.jpg
#   inflating: AID/Parking/parking_176.jpg
#   inflating: AID/Parking/parking_177.jpg
#   inflating: AID/Parking/parking_178.jpg
#   inflating: AID/Parking/parking_179.jpg
#   inflating: AID/Parking/parking_18.jpg
#   inflating: AID/Parking/parking_180.jpg
#   inflating: AID/Parking/parking_181.jpg
#   inflating: AID/Parking/parking_182.jpg
#   inflating: AID/Parking/parking_183.jpg
#   inflating: AID/Parking/parking_184.jpg
#   inflating: AID/Parking/parking_185.jpg
#   inflating: AID/Parking/parking_186.jpg
#   inflating: AID/Parking/parking_187.jpg
#   inflating: AID/Parking/parking_188.jpg
#   inflating: AID/Parking/parking_189.jpg
#   inflating: AID/Parking/parking_19.jpg
#   inflating: AID/Parking/parking_190.jpg
#   inflating: AID/Parking/parking_191.jpg
#   inflating: AID/Parking/parking_192.jpg
#   inflating: AID/Parking/parking_193.jpg
#   inflating: AID/Parking/parking_194.jpg
#   inflating: AID/Parking/parking_195.jpg
#   inflating: AID/Parking/parking_196.jpg
#   inflating: AID/Parking/parking_197.jpg
#   inflating: AID/Parking/parking_198.jpg
#   inflating: AID/Parking/parking_199.jpg
#   inflating: AID/Parking/parking_2.jpg
#   inflating: AID/Parking/parking_20.jpg
#   inflating: AID/Parking/parking_200.jpg
#   inflating: AID/Parking/parking_201.jpg
#   inflating: AID/Parking/parking_202.jpg
#   inflating: AID/Parking/parking_203.jpg
#   inflating: AID/Parking/parking_204.jpg
#   inflating: AID/Parking/parking_205.jpg
#   inflating: AID/Parking/parking_206.jpg
#   inflating: AID/Parking/parking_207.jpg
#   inflating: AID/Parking/parking_208.jpg
#   inflating: AID/Parking/parking_209.jpg
#   inflating: AID/Parking/parking_21.jpg
#   inflating: AID/Parking/parking_210.jpg
#   inflating: AID/Parking/parking_211.jpg
#   inflating: AID/Parking/parking_212.jpg
#   inflating: AID/Parking/parking_213.jpg
#   inflating: AID/Parking/parking_214.jpg
#   inflating: AID/Parking/parking_215.jpg
#   inflating: AID/Parking/parking_216.jpg
#   inflating: AID/Parking/parking_217.jpg
#   inflating: AID/Parking/parking_218.jpg
#   inflating: AID/Parking/parking_219.jpg
#   inflating: AID/Parking/parking_22.jpg
#   inflating: AID/Parking/parking_220.jpg
#   inflating: AID/Parking/parking_221.jpg
#   inflating: AID/Parking/parking_222.jpg
#   inflating: AID/Parking/parking_223.jpg
#   inflating: AID/Parking/parking_224.jpg
#   inflating: AID/Parking/parking_225.jpg
#   inflating: AID/Parking/parking_226.jpg
#   inflating: AID/Parking/parking_227.jpg
#   inflating: AID/Parking/parking_228.jpg
#   inflating: AID/Parking/parking_229.jpg
#   inflating: AID/Parking/parking_23.jpg
#   inflating: AID/Parking/parking_230.jpg
#   inflating: AID/Parking/parking_231.jpg
#   inflating: AID/Parking/parking_232.jpg
#   inflating: AID/Parking/parking_233.jpg
#   inflating: AID/Parking/parking_234.jpg
#   inflating: AID/Parking/parking_235.jpg
#   inflating: AID/Parking/parking_236.jpg
#   inflating: AID/Parking/parking_237.jpg
#   inflating: AID/Parking/parking_238.jpg
#   inflating: AID/Parking/parking_239.jpg
#   inflating: AID/Parking/parking_24.jpg
#   inflating: AID/Parking/parking_240.jpg
#   inflating: AID/Parking/parking_241.jpg
#   inflating: AID/Parking/parking_242.jpg
#   inflating: AID/Parking/parking_243.jpg
#   inflating: AID/Parking/parking_244.jpg
#   inflating: AID/Parking/parking_245.jpg
#   inflating: AID/Parking/parking_246.jpg
#   inflating: AID/Parking/parking_247.jpg
#   inflating: AID/Parking/parking_248.jpg
#   inflating: AID/Parking/parking_249.jpg
#   inflating: AID/Parking/parking_25.jpg
#   inflating: AID/Parking/parking_250.jpg
#   inflating: AID/Parking/parking_251.jpg
#   inflating: AID/Parking/parking_252.jpg
#   inflating: AID/Parking/parking_253.jpg
#   inflating: AID/Parking/parking_254.jpg
#   inflating: AID/Parking/parking_255.jpg
#   inflating: AID/Parking/parking_256.jpg
#   inflating: AID/Parking/parking_257.jpg
#   inflating: AID/Parking/parking_258.jpg
#   inflating: AID/Parking/parking_259.jpg
#   inflating: AID/Parking/parking_26.jpg
#   inflating: AID/Parking/parking_260.jpg
#   inflating: AID/Parking/parking_261.jpg
#   inflating: AID/Parking/parking_262.jpg
#   inflating: AID/Parking/parking_263.jpg
#   inflating: AID/Parking/parking_264.jpg
#   inflating: AID/Parking/parking_265.jpg
#   inflating: AID/Parking/parking_266.jpg
#   inflating: AID/Parking/parking_267.jpg
#   inflating: AID/Parking/parking_268.jpg
#   inflating: AID/Parking/parking_269.jpg
#   inflating: AID/Parking/parking_27.jpg
#   inflating: AID/Parking/parking_270.jpg
#   inflating: AID/Parking/parking_271.jpg
#   inflating: AID/Parking/parking_272.jpg
#   inflating: AID/Parking/parking_273.jpg
#   inflating: AID/Parking/parking_274.jpg
#   inflating: AID/Parking/parking_275.jpg
#   inflating: AID/Parking/parking_276.jpg
#   inflating: AID/Parking/parking_277.jpg
#   inflating: AID/Parking/parking_278.jpg
#   inflating: AID/Parking/parking_279.jpg
#   inflating: AID/Parking/parking_28.jpg
#   inflating: AID/Parking/parking_280.jpg
#   inflating: AID/Parking/parking_281.jpg
#   inflating: AID/Parking/parking_282.jpg
#   inflating: AID/Parking/parking_283.jpg
#   inflating: AID/Parking/parking_284.jpg
#   inflating: AID/Parking/parking_285.jpg
#   inflating: AID/Parking/parking_286.jpg
#   inflating: AID/Parking/parking_287.jpg
#   inflating: AID/Parking/parking_288.jpg
#   inflating: AID/Parking/parking_289.jpg
#   inflating: AID/Parking/parking_29.jpg
#   inflating: AID/Parking/parking_290.jpg
#   inflating: AID/Parking/parking_291.jpg
#   inflating: AID/Parking/parking_292.jpg
#   inflating: AID/Parking/parking_293.jpg
#   inflating: AID/Parking/parking_294.jpg
#   inflating: AID/Parking/parking_295.jpg
#   inflating: AID/Parking/parking_296.jpg
#   inflating: AID/Parking/parking_297.jpg
#   inflating: AID/Parking/parking_298.jpg
#   inflating: AID/Parking/parking_299.jpg
#   inflating: AID/Parking/parking_3.jpg
#   inflating: AID/Parking/parking_30.jpg
#   inflating: AID/Parking/parking_300.jpg
#   inflating: AID/Parking/parking_301.jpg
#   inflating: AID/Parking/parking_302.jpg
#   inflating: AID/Parking/parking_303.jpg
#   inflating: AID/Parking/parking_304.jpg
#   inflating: AID/Parking/parking_305.jpg
#   inflating: AID/Parking/parking_306.jpg
#   inflating: AID/Parking/parking_307.jpg
#   inflating: AID/Parking/parking_308.jpg
#   inflating: AID/Parking/parking_309.jpg
#   inflating: AID/Parking/parking_31.jpg
#   inflating: AID/Parking/parking_310.jpg
#   inflating: AID/Parking/parking_311.jpg
#   inflating: AID/Parking/parking_312.jpg
#   inflating: AID/Parking/parking_313.jpg
#   inflating: AID/Parking/parking_314.jpg
#   inflating: AID/Parking/parking_315.jpg
#   inflating: AID/Parking/parking_316.jpg
#   inflating: AID/Parking/parking_317.jpg
#   inflating: AID/Parking/parking_318.jpg
#   inflating: AID/Parking/parking_319.jpg
#   inflating: AID/Parking/parking_32.jpg
#   inflating: AID/Parking/parking_320.jpg
#   inflating: AID/Parking/parking_321.jpg
#   inflating: AID/Parking/parking_322.jpg
#   inflating: AID/Parking/parking_323.jpg
#   inflating: AID/Parking/parking_324.jpg
#   inflating: AID/Parking/parking_325.jpg
#   inflating: AID/Parking/parking_326.jpg
#   inflating: AID/Parking/parking_327.jpg
#   inflating: AID/Parking/parking_328.jpg
#   inflating: AID/Parking/parking_329.jpg
#   inflating: AID/Parking/parking_33.jpg
#   inflating: AID/Parking/parking_330.jpg
#   inflating: AID/Parking/parking_331.jpg
#   inflating: AID/Parking/parking_332.jpg
#   inflating: AID/Parking/parking_333.jpg
#   inflating: AID/Parking/parking_334.jpg
#   inflating: AID/Parking/parking_335.jpg
#   inflating: AID/Parking/parking_336.jpg
#   inflating: AID/Parking/parking_337.jpg
#   inflating: AID/Parking/parking_338.jpg
#   inflating: AID/Parking/parking_339.jpg
#   inflating: AID/Parking/parking_34.jpg
#   inflating: AID/Parking/parking_340.jpg
#   inflating: AID/Parking/parking_341.jpg
#   inflating: AID/Parking/parking_342.jpg
#   inflating: AID/Parking/parking_343.jpg
#   inflating: AID/Parking/parking_344.jpg
#   inflating: AID/Parking/parking_345.jpg
#   inflating: AID/Parking/parking_346.jpg
#   inflating: AID/Parking/parking_347.jpg
#   inflating: AID/Parking/parking_348.jpg
#   inflating: AID/Parking/parking_349.jpg
#   inflating: AID/Parking/parking_35.jpg
#   inflating: AID/Parking/parking_350.jpg
#   inflating: AID/Parking/parking_351.jpg
#   inflating: AID/Parking/parking_352.jpg
#   inflating: AID/Parking/parking_353.jpg
#   inflating: AID/Parking/parking_354.jpg
#   inflating: AID/Parking/parking_355.jpg
#   inflating: AID/Parking/parking_356.jpg
#   inflating: AID/Parking/parking_357.jpg
#   inflating: AID/Parking/parking_358.jpg
#   inflating: AID/Parking/parking_359.jpg
#   inflating: AID/Parking/parking_36.jpg
#   inflating: AID/Parking/parking_360.jpg
#   inflating: AID/Parking/parking_361.jpg
#   inflating: AID/Parking/parking_362.jpg
#   inflating: AID/Parking/parking_363.jpg
#   inflating: AID/Parking/parking_364.jpg
#   inflating: AID/Parking/parking_365.jpg
#   inflating: AID/Parking/parking_366.jpg
#   inflating: AID/Parking/parking_367.jpg
#   inflating: AID/Parking/parking_368.jpg
#   inflating: AID/Parking/parking_369.jpg
#   inflating: AID/Parking/parking_37.jpg
#   inflating: AID/Parking/parking_370.jpg
#   inflating: AID/Parking/parking_371.jpg
#   inflating: AID/Parking/parking_372.jpg
#   inflating: AID/Parking/parking_373.jpg
#   inflating: AID/Parking/parking_374.jpg
#   inflating: AID/Parking/parking_375.jpg
#   inflating: AID/Parking/parking_376.jpg
#   inflating: AID/Parking/parking_377.jpg
#   inflating: AID/Parking/parking_378.jpg
#   inflating: AID/Parking/parking_379.jpg
#   inflating: AID/Parking/parking_38.jpg
#   inflating: AID/Parking/parking_380.jpg
#   inflating: AID/Parking/parking_381.jpg
#   inflating: AID/Parking/parking_382.jpg
#   inflating: AID/Parking/parking_383.jpg
#   inflating: AID/Parking/parking_384.jpg
#   inflating: AID/Parking/parking_385.jpg
#   inflating: AID/Parking/parking_386.jpg
#   inflating: AID/Parking/parking_387.jpg
#   inflating: AID/Parking/parking_388.jpg
#   inflating: AID/Parking/parking_389.jpg
#   inflating: AID/Parking/parking_39.jpg
#   inflating: AID/Parking/parking_390.jpg
#   inflating: AID/Parking/parking_4.jpg
#   inflating: AID/Parking/parking_40.jpg
#   inflating: AID/Parking/parking_41.jpg
#   inflating: AID/Parking/parking_42.jpg
#   inflating: AID/Parking/parking_43.jpg
#   inflating: AID/Parking/parking_44.jpg
#   inflating: AID/Parking/parking_45.jpg
#   inflating: AID/Parking/parking_46.jpg
#   inflating: AID/Parking/parking_47.jpg
#   inflating: AID/Parking/parking_48.jpg
#   inflating: AID/Parking/parking_49.jpg
#   inflating: AID/Parking/parking_5.jpg
#   inflating: AID/Parking/parking_50.jpg
#   inflating: AID/Parking/parking_51.jpg
#   inflating: AID/Parking/parking_52.jpg
#   inflating: AID/Parking/parking_53.jpg
#   inflating: AID/Parking/parking_54.jpg
#   inflating: AID/Parking/parking_55.jpg
#   inflating: AID/Parking/parking_56.jpg
#   inflating: AID/Parking/parking_57.jpg
#   inflating: AID/Parking/parking_58.jpg
#   inflating: AID/Parking/parking_59.jpg
#   inflating: AID/Parking/parking_6.jpg
#   inflating: AID/Parking/parking_60.jpg
#   inflating: AID/Parking/parking_61.jpg
#   inflating: AID/Parking/parking_62.jpg
#   inflating: AID/Parking/parking_63.jpg
#   inflating: AID/Parking/parking_64.jpg
#   inflating: AID/Parking/parking_65.jpg
#   inflating: AID/Parking/parking_66.jpg
#   inflating: AID/Parking/parking_67.jpg
#   inflating: AID/Parking/parking_68.jpg
#   inflating: AID/Parking/parking_69.jpg
#   inflating: AID/Parking/parking_7.jpg
#   inflating: AID/Parking/parking_70.jpg
#   inflating: AID/Parking/parking_71.jpg
#   inflating: AID/Parking/parking_72.jpg
#   inflating: AID/Parking/parking_73.jpg
#   inflating: AID/Parking/parking_74.jpg
#   inflating: AID/Parking/parking_75.jpg
#   inflating: AID/Parking/parking_76.jpg
#   inflating: AID/Parking/parking_77.jpg
#   inflating: AID/Parking/parking_78.jpg
#   inflating: AID/Parking/parking_79.jpg
#   inflating: AID/Parking/parking_8.jpg
#   inflating: AID/Parking/parking_80.jpg
#   inflating: AID/Parking/parking_81.jpg
#   inflating: AID/Parking/parking_82.jpg
#   inflating: AID/Parking/parking_83.jpg
#   inflating: AID/Parking/parking_84.jpg
#   inflating: AID/Parking/parking_85.jpg
#   inflating: AID/Parking/parking_86.jpg
#   inflating: AID/Parking/parking_87.jpg
#   inflating: AID/Parking/parking_88.jpg
#   inflating: AID/Parking/parking_89.jpg
#   inflating: AID/Parking/parking_9.jpg
#   inflating: AID/Parking/parking_90.jpg
#   inflating: AID/Parking/parking_91.jpg
#   inflating: AID/Parking/parking_92.jpg
#   inflating: AID/Parking/parking_93.jpg
#   inflating: AID/Parking/parking_94.jpg
#   inflating: AID/Parking/parking_95.jpg
#   inflating: AID/Parking/parking_96.jpg
#   inflating: AID/Parking/parking_97.jpg
#   inflating: AID/Parking/parking_98.jpg
#   inflating: AID/Parking/parking_99.jpg
#    creating: AID/Playground/
#   inflating: AID/Playground/playground_1.jpg
#   inflating: AID/Playground/playground_10.jpg
#   inflating: AID/Playground/playground_100.jpg
#   inflating: AID/Playground/playground_101.jpg
#   inflating: AID/Playground/playground_102.jpg
#   inflating: AID/Playground/playground_103.jpg
#   inflating: AID/Playground/playground_104.jpg
#   inflating: AID/Playground/playground_105.jpg
#   inflating: AID/Playground/playground_106.jpg
#   inflating: AID/Playground/playground_107.jpg
#   inflating: AID/Playground/playground_108.jpg
#   inflating: AID/Playground/playground_109.jpg
#   inflating: AID/Playground/playground_11.jpg
#   inflating: AID/Playground/playground_110.jpg
#   inflating: AID/Playground/playground_111.jpg
#   inflating: AID/Playground/playground_112.jpg
#   inflating: AID/Playground/playground_113.jpg
#   inflating: AID/Playground/playground_114.jpg
#   inflating: AID/Playground/playground_115.jpg
#   inflating: AID/Playground/playground_116.jpg
#   inflating: AID/Playground/playground_117.jpg
#   inflating: AID/Playground/playground_118.jpg
#   inflating: AID/Playground/playground_119.jpg
#   inflating: AID/Playground/playground_12.jpg
#   inflating: AID/Playground/playground_120.jpg
#   inflating: AID/Playground/playground_121.jpg
#   inflating: AID/Playground/playground_122.jpg
#   inflating: AID/Playground/playground_123.jpg
#   inflating: AID/Playground/playground_124.jpg
#   inflating: AID/Playground/playground_125.jpg
#   inflating: AID/Playground/playground_126.jpg
#   inflating: AID/Playground/playground_127.jpg
#   inflating: AID/Playground/playground_128.jpg
#   inflating: AID/Playground/playground_129.jpg
#   inflating: AID/Playground/playground_13.jpg
#   inflating: AID/Playground/playground_130.jpg
#   inflating: AID/Playground/playground_131.jpg
#   inflating: AID/Playground/playground_132.jpg
#   inflating: AID/Playground/playground_133.jpg
#   inflating: AID/Playground/playground_134.jpg
#   inflating: AID/Playground/playground_135.jpg
#   inflating: AID/Playground/playground_136.jpg
#   inflating: AID/Playground/playground_137.jpg
#   inflating: AID/Playground/playground_138.jpg
#   inflating: AID/Playground/playground_139.jpg
#   inflating: AID/Playground/playground_14.jpg
#   inflating: AID/Playground/playground_140.jpg
#   inflating: AID/Playground/playground_141.jpg
#   inflating: AID/Playground/playground_142.jpg
#   inflating: AID/Playground/playground_143.jpg
#   inflating: AID/Playground/playground_144.jpg
#   inflating: AID/Playground/playground_145.jpg
#   inflating: AID/Playground/playground_146.jpg
#   inflating: AID/Playground/playground_147.jpg
#   inflating: AID/Playground/playground_148.jpg
#   inflating: AID/Playground/playground_149.jpg
#   inflating: AID/Playground/playground_15.jpg
#   inflating: AID/Playground/playground_150.jpg
#   inflating: AID/Playground/playground_151.jpg
#   inflating: AID/Playground/playground_152.jpg
#   inflating: AID/Playground/playground_153.jpg
#   inflating: AID/Playground/playground_154.jpg
#   inflating: AID/Playground/playground_155.jpg
#   inflating: AID/Playground/playground_156.jpg
#   inflating: AID/Playground/playground_157.jpg
#   inflating: AID/Playground/playground_158.jpg
#   inflating: AID/Playground/playground_159.jpg
#   inflating: AID/Playground/playground_16.jpg
#   inflating: AID/Playground/playground_160.jpg
#   inflating: AID/Playground/playground_161.jpg
#   inflating: AID/Playground/playground_162.jpg
#   inflating: AID/Playground/playground_163.jpg
#   inflating: AID/Playground/playground_164.jpg
#   inflating: AID/Playground/playground_165.jpg
#   inflating: AID/Playground/playground_166.jpg
#   inflating: AID/Playground/playground_167.jpg
#   inflating: AID/Playground/playground_168.jpg
#   inflating: AID/Playground/playground_169.jpg
#   inflating: AID/Playground/playground_17.jpg
#   inflating: AID/Playground/playground_170.jpg
#   inflating: AID/Playground/playground_171.jpg
#   inflating: AID/Playground/playground_172.jpg
#   inflating: AID/Playground/playground_173.jpg
#   inflating: AID/Playground/playground_174.jpg
#   inflating: AID/Playground/playground_175.jpg
#   inflating: AID/Playground/playground_176.jpg
#   inflating: AID/Playground/playground_177.jpg
#   inflating: AID/Playground/playground_178.jpg
#   inflating: AID/Playground/playground_179.jpg
#   inflating: AID/Playground/playground_18.jpg
#   inflating: AID/Playground/playground_180.jpg
#   inflating: AID/Playground/playground_181.jpg
#   inflating: AID/Playground/playground_182.jpg
#   inflating: AID/Playground/playground_183.jpg
#   inflating: AID/Playground/playground_184.jpg
#   inflating: AID/Playground/playground_185.jpg
#   inflating: AID/Playground/playground_186.jpg
#   inflating: AID/Playground/playground_187.jpg
#   inflating: AID/Playground/playground_188.jpg
#   inflating: AID/Playground/playground_189.jpg
#   inflating: AID/Playground/playground_19.jpg
#   inflating: AID/Playground/playground_190.jpg
#   inflating: AID/Playground/playground_191.jpg
#   inflating: AID/Playground/playground_192.jpg
#   inflating: AID/Playground/playground_193.jpg
#   inflating: AID/Playground/playground_194.jpg
#   inflating: AID/Playground/playground_195.jpg
#   inflating: AID/Playground/playground_196.jpg
#   inflating: AID/Playground/playground_197.jpg
#   inflating: AID/Playground/playground_198.jpg
#   inflating: AID/Playground/playground_199.jpg
#   inflating: AID/Playground/playground_2.jpg
#   inflating: AID/Playground/playground_20.jpg
#   inflating: AID/Playground/playground_200.jpg
#   inflating: AID/Playground/playground_201.jpg
#   inflating: AID/Playground/playground_202.jpg
#   inflating: AID/Playground/playground_203.jpg
#   inflating: AID/Playground/playground_204.jpg
#   inflating: AID/Playground/playground_205.jpg
#   inflating: AID/Playground/playground_206.jpg
#   inflating: AID/Playground/playground_207.jpg
#   inflating: AID/Playground/playground_208.jpg
#   inflating: AID/Playground/playground_209.jpg
#   inflating: AID/Playground/playground_21.jpg
#   inflating: AID/Playground/playground_210.jpg
#   inflating: AID/Playground/playground_211.jpg
#   inflating: AID/Playground/playground_212.jpg
#   inflating: AID/Playground/playground_213.jpg
#   inflating: AID/Playground/playground_214.jpg
#   inflating: AID/Playground/playground_215.jpg
#   inflating: AID/Playground/playground_216.jpg
#   inflating: AID/Playground/playground_217.jpg
#   inflating: AID/Playground/playground_218.jpg
#   inflating: AID/Playground/playground_219.jpg
#   inflating: AID/Playground/playground_22.jpg
#   inflating: AID/Playground/playground_220.jpg
#   inflating: AID/Playground/playground_221.jpg
#   inflating: AID/Playground/playground_222.jpg
#   inflating: AID/Playground/playground_223.jpg
#   inflating: AID/Playground/playground_224.jpg
#   inflating: AID/Playground/playground_225.jpg
#   inflating: AID/Playground/playground_226.jpg
#   inflating: AID/Playground/playground_227.jpg
#   inflating: AID/Playground/playground_228.jpg
#   inflating: AID/Playground/playground_229.jpg
#   inflating: AID/Playground/playground_23.jpg
#   inflating: AID/Playground/playground_230.jpg
#   inflating: AID/Playground/playground_231.jpg
#   inflating: AID/Playground/playground_232.jpg
#   inflating: AID/Playground/playground_233.jpg
#   inflating: AID/Playground/playground_234.jpg
#   inflating: AID/Playground/playground_235.jpg
#   inflating: AID/Playground/playground_236.jpg
#   inflating: AID/Playground/playground_237.jpg
#   inflating: AID/Playground/playground_238.jpg
#   inflating: AID/Playground/playground_239.jpg
#   inflating: AID/Playground/playground_24.jpg
#   inflating: AID/Playground/playground_240.jpg
#   inflating: AID/Playground/playground_241.jpg
#   inflating: AID/Playground/playground_242.jpg
#   inflating: AID/Playground/playground_243.jpg
#   inflating: AID/Playground/playground_244.jpg
#   inflating: AID/Playground/playground_245.jpg
#   inflating: AID/Playground/playground_246.jpg
#   inflating: AID/Playground/playground_247.jpg
#   inflating: AID/Playground/playground_248.jpg
#   inflating: AID/Playground/playground_249.jpg
#   inflating: AID/Playground/playground_25.jpg
#   inflating: AID/Playground/playground_250.jpg
#   inflating: AID/Playground/playground_251.jpg
#   inflating: AID/Playground/playground_252.jpg
#   inflating: AID/Playground/playground_253.jpg
#   inflating: AID/Playground/playground_254.jpg
#   inflating: AID/Playground/playground_255.jpg
#   inflating: AID/Playground/playground_256.jpg
#   inflating: AID/Playground/playground_257.jpg
#   inflating: AID/Playground/playground_258.jpg
#   inflating: AID/Playground/playground_259.jpg
#   inflating: AID/Playground/playground_26.jpg
#   inflating: AID/Playground/playground_260.jpg
#   inflating: AID/Playground/playground_261.jpg
#   inflating: AID/Playground/playground_262.jpg
#   inflating: AID/Playground/playground_263.jpg
#   inflating: AID/Playground/playground_264.jpg
#   inflating: AID/Playground/playground_265.jpg
#   inflating: AID/Playground/playground_266.jpg
#   inflating: AID/Playground/playground_267.jpg
#   inflating: AID/Playground/playground_268.jpg
#   inflating: AID/Playground/playground_269.jpg
#   inflating: AID/Playground/playground_27.jpg
#   inflating: AID/Playground/playground_270.jpg
#   inflating: AID/Playground/playground_271.jpg
#   inflating: AID/Playground/playground_272.jpg
#   inflating: AID/Playground/playground_273.jpg
#   inflating: AID/Playground/playground_274.jpg
#   inflating: AID/Playground/playground_275.jpg
#   inflating: AID/Playground/playground_276.jpg
#   inflating: AID/Playground/playground_277.jpg
#   inflating: AID/Playground/playground_278.jpg
#   inflating: AID/Playground/playground_279.jpg
#   inflating: AID/Playground/playground_28.jpg
#   inflating: AID/Playground/playground_280.jpg
#   inflating: AID/Playground/playground_281.jpg
#   inflating: AID/Playground/playground_282.jpg
#   inflating: AID/Playground/playground_283.jpg
#   inflating: AID/Playground/playground_284.jpg
#   inflating: AID/Playground/playground_285.jpg
#   inflating: AID/Playground/playground_286.jpg
#   inflating: AID/Playground/playground_287.jpg
#   inflating: AID/Playground/playground_288.jpg
#   inflating: AID/Playground/playground_289.jpg
#   inflating: AID/Playground/playground_29.jpg
#   inflating: AID/Playground/playground_290.jpg
#   inflating: AID/Playground/playground_291.jpg
#   inflating: AID/Playground/playground_292.jpg
#   inflating: AID/Playground/playground_293.jpg
#   inflating: AID/Playground/playground_294.jpg
#   inflating: AID/Playground/playground_295.jpg
#   inflating: AID/Playground/playground_296.jpg
#   inflating: AID/Playground/playground_297.jpg
#   inflating: AID/Playground/playground_298.jpg
#   inflating: AID/Playground/playground_299.jpg
#   inflating: AID/Playground/playground_3.jpg
#   inflating: AID/Playground/playground_30.jpg
#   inflating: AID/Playground/playground_300.jpg
#   inflating: AID/Playground/playground_301.jpg
#   inflating: AID/Playground/playground_302.jpg
#   inflating: AID/Playground/playground_303.jpg
#   inflating: AID/Playground/playground_304.jpg
#   inflating: AID/Playground/playground_305.jpg
#   inflating: AID/Playground/playground_306.jpg
#   inflating: AID/Playground/playground_307.jpg
#   inflating: AID/Playground/playground_308.jpg
#   inflating: AID/Playground/playground_309.jpg
#   inflating: AID/Playground/playground_31.jpg
#   inflating: AID/Playground/playground_310.jpg
#   inflating: AID/Playground/playground_311.jpg
#   inflating: AID/Playground/playground_312.jpg
#   inflating: AID/Playground/playground_313.jpg
#   inflating: AID/Playground/playground_314.jpg
#   inflating: AID/Playground/playground_315.jpg
#   inflating: AID/Playground/playground_316.jpg
#   inflating: AID/Playground/playground_317.jpg
#   inflating: AID/Playground/playground_318.jpg
#   inflating: AID/Playground/playground_319.jpg
#   inflating: AID/Playground/playground_32.jpg
#   inflating: AID/Playground/playground_320.jpg
#   inflating: AID/Playground/playground_321.jpg
#   inflating: AID/Playground/playground_322.jpg
#   inflating: AID/Playground/playground_323.jpg
#   inflating: AID/Playground/playground_324.jpg
#   inflating: AID/Playground/playground_325.jpg
#   inflating: AID/Playground/playground_326.jpg
#   inflating: AID/Playground/playground_327.jpg
#   inflating: AID/Playground/playground_328.jpg
#   inflating: AID/Playground/playground_329.jpg
#   inflating: AID/Playground/playground_33.jpg
#   inflating: AID/Playground/playground_330.jpg
#   inflating: AID/Playground/playground_331.jpg
#   inflating: AID/Playground/playground_332.jpg
#   inflating: AID/Playground/playground_333.jpg
# ...
#   inflating: AID/Viaduct/viaduct_140.jpg
#   inflating: AID/Viaduct/viaduct_141.jpg
#   inflating: AID/Viaduct/viaduct_142.jpg
#   inflating: AID/Viaduct/viaduct_143.jpg
#   inflating: AID/Viaduct/viaduct_144.jpg
#   inflating: AID/Viaduct/viaduct_145.jpg
#   inflating: AID/Viaduct/viaduct_146.jpg
#   inflating: AID/Viaduct/viaduct_147.jpg
#   inflating: AID/Viaduct/viaduct_148.jpg
#   inflating: AID/Viaduct/viaduct_149.jpg
#   inflating: AID/Viaduct/viaduct_15.jpg
#   inflating: AID/Viaduct/viaduct_150.jpg
#   inflating: AID/Viaduct/viaduct_151.jpg
#   inflating: AID/Viaduct/viaduct_152.jpg
#   inflating: AID/Viaduct/viaduct_153.jpg
#   inflating: AID/Viaduct/viaduct_154.jpg
#   inflating: AID/Viaduct/viaduct_155.jpg
#   inflating: AID/Viaduct/viaduct_156.jpg
#   inflating: AID/Viaduct/viaduct_157.jpg
#   inflating: AID/Viaduct/viaduct_158.jpg
#   inflating: AID/Viaduct/viaduct_159.jpg
#   inflating: AID/Viaduct/viaduct_16.jpg
#   inflating: AID/Viaduct/viaduct_160.jpg
#   inflating: AID/Viaduct/viaduct_161.jpg
#   inflating: AID/Viaduct/viaduct_162.jpg
#   inflating: AID/Viaduct/viaduct_163.jpg
#   inflating: AID/Viaduct/viaduct_164.jpg
#   inflating: AID/Viaduct/viaduct_165.jpg
#   inflating: AID/Viaduct/viaduct_166.jpg
#   inflating: AID/Viaduct/viaduct_167.jpg
#   inflating: AID/Viaduct/viaduct_168.jpg
#   inflating: AID/Viaduct/viaduct_169.jpg
#   inflating: AID/Viaduct/viaduct_17.jpg
#   inflating: AID/Viaduct/viaduct_170.jpg
#   inflating: AID/Viaduct/viaduct_171.jpg
#   inflating: AID/Viaduct/viaduct_172.jpg
#   inflating: AID/Viaduct/viaduct_173.jpg
#   inflating: AID/Viaduct/viaduct_174.jpg
#   inflating: AID/Viaduct/viaduct_175.jpg
#   inflating: AID/Viaduct/viaduct_176.jpg
#   inflating: AID/Viaduct/viaduct_177.jpg
#   inflating: AID/Viaduct/viaduct_178.jpg
#   inflating: AID/Viaduct/viaduct_179.jpg
#   inflating: AID/Viaduct/viaduct_18.jpg
#   inflating: AID/Viaduct/viaduct_180.jpg
#   inflating: AID/Viaduct/viaduct_181.jpg
#   inflating: AID/Viaduct/viaduct_182.jpg
#   inflating: AID/Viaduct/viaduct_183.jpg
#   inflating: AID/Viaduct/viaduct_184.jpg
#   inflating: AID/Viaduct/viaduct_185.jpg
#   inflating: AID/Viaduct/viaduct_186.jpg
#   inflating: AID/Viaduct/viaduct_187.jpg
#   inflating: AID/Viaduct/viaduct_188.jpg
#   inflating: AID/Viaduct/viaduct_189.jpg
#   inflating: AID/Viaduct/viaduct_19.jpg
#   inflating: AID/Viaduct/viaduct_190.jpg
#   inflating: AID/Viaduct/viaduct_191.jpg
#   inflating: AID/Viaduct/viaduct_192.jpg
#   inflating: AID/Viaduct/viaduct_193.jpg
#   inflating: AID/Viaduct/viaduct_194.jpg
#   inflating: AID/Viaduct/viaduct_195.jpg
#   inflating: AID/Viaduct/viaduct_196.jpg
#   inflating: AID/Viaduct/viaduct_197.jpg
#   inflating: AID/Viaduct/viaduct_198.jpg
#   inflating: AID/Viaduct/viaduct_199.jpg
#   inflating: AID/Viaduct/viaduct_2.jpg
#   inflating: AID/Viaduct/viaduct_20.jpg
#   inflating: AID/Viaduct/viaduct_200.jpg
#   inflating: AID/Viaduct/viaduct_201.jpg
#   inflating: AID/Viaduct/viaduct_202.jpg
#   inflating: AID/Viaduct/viaduct_203.jpg
#   inflating: AID/Viaduct/viaduct_204.jpg
#   inflating: AID/Viaduct/viaduct_205.jpg
#   inflating: AID/Viaduct/viaduct_206.jpg
#   inflating: AID/Viaduct/viaduct_207.jpg
#   inflating: AID/Viaduct/viaduct_208.jpg
#   inflating: AID/Viaduct/viaduct_209.jpg
#   inflating: AID/Viaduct/viaduct_21.jpg
#   inflating: AID/Viaduct/viaduct_210.jpg
#   inflating: AID/Viaduct/viaduct_211.jpg
#   inflating: AID/Viaduct/viaduct_212.jpg
#   inflating: AID/Viaduct/viaduct_213.jpg
#   inflating: AID/Viaduct/viaduct_214.jpg
#   inflating: AID/Viaduct/viaduct_215.jpg
#   inflating: AID/Viaduct/viaduct_216.jpg
#   inflating: AID/Viaduct/viaduct_217.jpg
#   inflating: AID/Viaduct/viaduct_218.jpg
#   inflating: AID/Viaduct/viaduct_219.jpg
#   inflating: AID/Viaduct/viaduct_22.jpg
#   inflating: AID/Viaduct/viaduct_220.jpg
#   inflating: AID/Viaduct/viaduct_221.jpg
#   inflating: AID/Viaduct/viaduct_222.jpg
#   inflating: AID/Viaduct/viaduct_223.jpg
#   inflating: AID/Viaduct/viaduct_224.jpg
#   inflating: AID/Viaduct/viaduct_225.jpg
#   inflating: AID/Viaduct/viaduct_226.jpg
#   inflating: AID/Viaduct/viaduct_227.jpg
#   inflating: AID/Viaduct/viaduct_228.jpg
#   inflating: AID/Viaduct/viaduct_229.jpg
#   inflating: AID/Viaduct/viaduct_23.jpg
#   inflating: AID/Viaduct/viaduct_230.jpg
#   inflating: AID/Viaduct/viaduct_231.jpg
#   inflating: AID/Viaduct/viaduct_232.jpg
#   inflating: AID/Viaduct/viaduct_233.jpg
#   inflating: AID/Viaduct/viaduct_234.jpg
#   inflating: AID/Viaduct/viaduct_235.jpg
#   inflating: AID/Viaduct/viaduct_236.jpg
#   inflating: AID/Viaduct/viaduct_237.jpg
#   inflating: AID/Viaduct/viaduct_238.jpg
#   inflating: AID/Viaduct/viaduct_239.jpg
#   inflating: AID/Viaduct/viaduct_24.jpg
#   inflating: AID/Viaduct/viaduct_240.jpg
#   inflating: AID/Viaduct/viaduct_241.jpg
#   inflating: AID/Viaduct/viaduct_242.jpg
#   inflating: AID/Viaduct/viaduct_243.jpg
#   inflating: AID/Viaduct/viaduct_244.jpg
#   inflating: AID/Viaduct/viaduct_245.jpg
#   inflating: AID/Viaduct/viaduct_246.jpg
#   inflating: AID/Viaduct/viaduct_247.jpg
#   inflating: AID/Viaduct/viaduct_248.jpg
#   inflating: AID/Viaduct/viaduct_249.jpg
#   inflating: AID/Viaduct/viaduct_25.jpg
#   inflating: AID/Viaduct/viaduct_250.jpg
#   inflating: AID/Viaduct/viaduct_251.jpg
#   inflating: AID/Viaduct/viaduct_252.jpg
#   inflating: AID/Viaduct/viaduct_253.jpg
#   inflating: AID/Viaduct/viaduct_254.jpg
#   inflating: AID/Viaduct/viaduct_255.jpg
#   inflating: AID/Viaduct/viaduct_256.jpg
#   inflating: AID/Viaduct/viaduct_257.jpg
#   inflating: AID/Viaduct/viaduct_258.jpg
#   inflating: AID/Viaduct/viaduct_259.jpg
#   inflating: AID/Viaduct/viaduct_26.jpg
#   inflating: AID/Viaduct/viaduct_260.jpg
#   inflating: AID/Viaduct/viaduct_261.jpg
#   inflating: AID/Viaduct/viaduct_262.jpg
#   inflating: AID/Viaduct/viaduct_263.jpg
#   inflating: AID/Viaduct/viaduct_264.jpg
#   inflating: AID/Viaduct/viaduct_265.jpg
#   inflating: AID/Viaduct/viaduct_266.jpg
#   inflating: AID/Viaduct/viaduct_267.jpg
#   inflating: AID/Viaduct/viaduct_268.jpg
#   inflating: AID/Viaduct/viaduct_269.jpg
#   inflating: AID/Viaduct/viaduct_27.jpg
#   inflating: AID/Viaduct/viaduct_270.jpg
#   inflating: AID/Viaduct/viaduct_271.jpg
#   inflating: AID/Viaduct/viaduct_272.jpg
#   inflating: AID/Viaduct/viaduct_273.jpg
#   inflating: AID/Viaduct/viaduct_274.jpg
#   inflating: AID/Viaduct/viaduct_275.jpg
#   inflating: AID/Viaduct/viaduct_276.jpg
#   inflating: AID/Viaduct/viaduct_277.jpg
#   inflating: AID/Viaduct/viaduct_278.jpg
#   inflating: AID/Viaduct/viaduct_279.jpg
#   inflating: AID/Viaduct/viaduct_28.jpg
#   inflating: AID/Viaduct/viaduct_280.jpg
#   inflating: AID/Viaduct/viaduct_281.jpg
#   inflating: AID/Viaduct/viaduct_282.jpg
#   inflating: AID/Viaduct/viaduct_283.jpg
#   inflating: AID/Viaduct/viaduct_284.jpg
#   inflating: AID/Viaduct/viaduct_285.jpg
#   inflating: AID/Viaduct/viaduct_286.jpg
#   inflating: AID/Viaduct/viaduct_287.jpg
#   inflating: AID/Viaduct/viaduct_288.jpg
#   inflating: AID/Viaduct/viaduct_289.jpg
#   inflating: AID/Viaduct/viaduct_29.jpg
#   inflating: AID/Viaduct/viaduct_290.jpg
#   inflating: AID/Viaduct/viaduct_291.jpg
#   inflating: AID/Viaduct/viaduct_292.jpg
#   inflating: AID/Viaduct/viaduct_293.jpg
#   inflating: AID/Viaduct/viaduct_294.jpg
#   inflating: AID/Viaduct/viaduct_295.jpg
#   inflating: AID/Viaduct/viaduct_296.jpg
#   inflating: AID/Viaduct/viaduct_297.jpg
#   inflating: AID/Viaduct/viaduct_298.jpg
#   inflating: AID/Viaduct/viaduct_299.jpg
#   inflating: AID/Viaduct/viaduct_3.jpg
#   inflating: AID/Viaduct/viaduct_30.jpg
#   inflating: AID/Viaduct/viaduct_300.jpg
#   inflating: AID/Viaduct/viaduct_301.jpg
#   inflating: AID/Viaduct/viaduct_302.jpg
#   inflating: AID/Viaduct/viaduct_303.jpg
#   inflating: AID/Viaduct/viaduct_304.jpg
#   inflating: AID/Viaduct/viaduct_305.jpg
#   inflating: AID/Viaduct/viaduct_306.jpg
#   inflating: AID/Viaduct/viaduct_307.jpg
#   inflating: AID/Viaduct/viaduct_308.jpg
#   inflating: AID/Viaduct/viaduct_309.jpg
#   inflating: AID/Viaduct/viaduct_31.jpg
#   inflating: AID/Viaduct/viaduct_310.jpg
#   inflating: AID/Viaduct/viaduct_311.jpg
#   inflating: AID/Viaduct/viaduct_312.jpg
#   inflating: AID/Viaduct/viaduct_313.jpg
#   inflating: AID/Viaduct/viaduct_314.jpg
#   inflating: AID/Viaduct/viaduct_315.jpg
#   inflating: AID/Viaduct/viaduct_316.jpg
#   inflating: AID/Viaduct/viaduct_317.jpg
#   inflating: AID/Viaduct/viaduct_318.jpg
#   inflating: AID/Viaduct/viaduct_319.jpg
#   inflating: AID/Viaduct/viaduct_32.jpg
#   inflating: AID/Viaduct/viaduct_320.jpg
#   inflating: AID/Viaduct/viaduct_321.jpg
#   inflating: AID/Viaduct/viaduct_322.jpg
#   inflating: AID/Viaduct/viaduct_323.jpg
#   inflating: AID/Viaduct/viaduct_324.jpg
#   inflating: AID/Viaduct/viaduct_325.jpg
#   inflating: AID/Viaduct/viaduct_326.jpg
#   inflating: AID/Viaduct/viaduct_327.jpg
#   inflating: AID/Viaduct/viaduct_328.jpg
#   inflating: AID/Viaduct/viaduct_329.jpg
#   inflating: AID/Viaduct/viaduct_33.jpg
#   inflating: AID/Viaduct/viaduct_330.jpg
#   inflating: AID/Viaduct/viaduct_331.jpg
#   inflating: AID/Viaduct/viaduct_332.jpg
#   inflating: AID/Viaduct/viaduct_333.jpg
#   inflating: AID/Viaduct/viaduct_334.jpg
#   inflating: AID/Viaduct/viaduct_335.jpg
#   inflating: AID/Viaduct/viaduct_336.jpg
#   inflating: AID/Viaduct/viaduct_337.jpg
#   inflating: AID/Viaduct/viaduct_338.jpg
#   inflating: AID/Viaduct/viaduct_339.jpg
#   inflating: AID/Viaduct/viaduct_34.jpg
#   inflating: AID/Viaduct/viaduct_340.jpg
#   inflating: AID/Viaduct/viaduct_341.jpg
#   inflating: AID/Viaduct/viaduct_342.jpg
#   inflating: AID/Viaduct/viaduct_343.jpg
#   inflating: AID/Viaduct/viaduct_344.jpg
#   inflating: AID/Viaduct/viaduct_345.jpg
#   inflating: AID/Viaduct/viaduct_346.jpg
#   inflating: AID/Viaduct/viaduct_347.jpg
#   inflating: AID/Viaduct/viaduct_348.jpg
#   inflating: AID/Viaduct/viaduct_349.jpg
#   inflating: AID/Viaduct/viaduct_35.jpg
#   inflating: AID/Viaduct/viaduct_350.jpg
#   inflating: AID/Viaduct/viaduct_351.jpg
#   inflating: AID/Viaduct/viaduct_352.jpg
#   inflating: AID/Viaduct/viaduct_353.jpg
#   inflating: AID/Viaduct/viaduct_354.jpg
#   inflating: AID/Viaduct/viaduct_355.jpg
#   inflating: AID/Viaduct/viaduct_356.jpg
#   inflating: AID/Viaduct/viaduct_357.jpg
#   inflating: AID/Viaduct/viaduct_358.jpg
#   inflating: AID/Viaduct/viaduct_359.jpg
#   inflating: AID/Viaduct/viaduct_36.jpg
#   inflating: AID/Viaduct/viaduct_360.jpg
#   inflating: AID/Viaduct/viaduct_361.jpg
#   inflating: AID/Viaduct/viaduct_362.jpg
#   inflating: AID/Viaduct/viaduct_363.jpg
#   inflating: AID/Viaduct/viaduct_364.jpg
#   inflating: AID/Viaduct/viaduct_365.jpg
#   inflating: AID/Viaduct/viaduct_366.jpg
#   inflating: AID/Viaduct/viaduct_367.jpg
#   inflating: AID/Viaduct/viaduct_368.jpg
#   inflating: AID/Viaduct/viaduct_369.jpg
#   inflating: AID/Viaduct/viaduct_37.jpg
#   inflating: AID/Viaduct/viaduct_370.jpg
#   inflating: AID/Viaduct/viaduct_371.jpg
#   inflating: AID/Viaduct/viaduct_372.jpg
#   inflating: AID/Viaduct/viaduct_373.jpg
#   inflating: AID/Viaduct/viaduct_374.jpg
#   inflating: AID/Viaduct/viaduct_375.jpg
#   inflating: AID/Viaduct/viaduct_376.jpg
#   inflating: AID/Viaduct/viaduct_377.jpg
#   inflating: AID/Viaduct/viaduct_378.jpg
#   inflating: AID/Viaduct/viaduct_379.jpg
#   inflating: AID/Viaduct/viaduct_38.jpg
#   inflating: AID/Viaduct/viaduct_380.jpg
#   inflating: AID/Viaduct/viaduct_381.jpg
#   inflating: AID/Viaduct/viaduct_382.jpg
#   inflating: AID/Viaduct/viaduct_383.jpg
#   inflating: AID/Viaduct/viaduct_384.jpg
#   inflating: AID/Viaduct/viaduct_385.jpg
#   inflating: AID/Viaduct/viaduct_386.jpg
#   inflating: AID/Viaduct/viaduct_387.jpg
#   inflating: AID/Viaduct/viaduct_388.jpg
#   inflating: AID/Viaduct/viaduct_389.jpg
#   inflating: AID/Viaduct/viaduct_39.jpg
#   inflating: AID/Viaduct/viaduct_390.jpg
#   inflating: AID/Viaduct/viaduct_391.jpg
#   inflating: AID/Viaduct/viaduct_392.jpg
#   inflating: AID/Viaduct/viaduct_393.jpg
#   inflating: AID/Viaduct/viaduct_394.jpg
#   inflating: AID/Viaduct/viaduct_395.jpg
#   inflating: AID/Viaduct/viaduct_396.jpg
#   inflating: AID/Viaduct/viaduct_397.jpg
#   inflating: AID/Viaduct/viaduct_398.jpg
#   inflating: AID/Viaduct/viaduct_399.jpg
#   inflating: AID/Viaduct/viaduct_4.jpg
#   inflating: AID/Viaduct/viaduct_40.jpg
#   inflating: AID/Viaduct/viaduct_400.jpg
#   inflating: AID/Viaduct/viaduct_401.jpg
#   inflating: AID/Viaduct/viaduct_402.jpg
#   inflating: AID/Viaduct/viaduct_403.jpg
#   inflating: AID/Viaduct/viaduct_404.jpg
#   inflating: AID/Viaduct/viaduct_405.jpg
#   inflating: AID/Viaduct/viaduct_406.jpg
#   inflating: AID/Viaduct/viaduct_407.jpg
#   inflating: AID/Viaduct/viaduct_408.jpg
#   inflating: AID/Viaduct/viaduct_409.jpg
#   inflating: AID/Viaduct/viaduct_41.jpg
#   inflating: AID/Viaduct/viaduct_410.jpg
#   inflating: AID/Viaduct/viaduct_411.jpg
#   inflating: AID/Viaduct/viaduct_412.jpg
#   inflating: AID/Viaduct/viaduct_413.jpg
#   inflating: AID/Viaduct/viaduct_414.jpg
#   inflating: AID/Viaduct/viaduct_415.jpg
#   inflating: AID/Viaduct/viaduct_416.jpg
#   inflating: AID/Viaduct/viaduct_417.jpg
#   inflating: AID/Viaduct/viaduct_418.jpg
#   inflating: AID/Viaduct/viaduct_419.jpg
#   inflating: AID/Viaduct/viaduct_42.jpg
#   inflating: AID/Viaduct/viaduct_420.jpg
#   inflating: AID/Viaduct/viaduct_43.jpg
#   inflating: AID/Viaduct/viaduct_44.jpg
#   inflating: AID/Viaduct/viaduct_45.jpg
#   inflating: AID/Viaduct/viaduct_46.jpg
#   inflating: AID/Viaduct/viaduct_47.jpg
#   inflating: AID/Viaduct/viaduct_48.jpg
#   inflating: AID/Viaduct/viaduct_49.jpg
#   inflating: AID/Viaduct/viaduct_5.jpg
#   inflating: AID/Viaduct/viaduct_50.jpg
#   inflating: AID/Viaduct/viaduct_51.jpg
#   inflating: AID/Viaduct/viaduct_52.jpg
#   inflating: AID/Viaduct/viaduct_53.jpg
#   inflating: AID/Viaduct/viaduct_54.jpg
#   inflating: AID/Viaduct/viaduct_55.jpg
#   inflating: AID/Viaduct/viaduct_56.jpg
#   inflating: AID/Viaduct/viaduct_57.jpg
#   inflating: AID/Viaduct/viaduct_58.jpg
#   inflating: AID/Viaduct/viaduct_59.jpg
#   inflating: AID/Viaduct/viaduct_6.jpg
#   inflating: AID/Viaduct/viaduct_60.jpg
#   inflating: AID/Viaduct/viaduct_61.jpg
#   inflating: AID/Viaduct/viaduct_62.jpg
#   inflating: AID/Viaduct/viaduct_63.jpg
#   inflating: AID/Viaduct/viaduct_64.jpg
#   inflating: AID/Viaduct/viaduct_65.jpg
#   inflating: AID/Viaduct/viaduct_66.jpg
#   inflating: AID/Viaduct/viaduct_67.jpg
#   inflating: AID/Viaduct/viaduct_68.jpg
#   inflating: AID/Viaduct/viaduct_69.jpg
#   inflating: AID/Viaduct/viaduct_7.jpg
#   inflating: AID/Viaduct/viaduct_70.jpg
#   inflating: AID/Viaduct/viaduct_71.jpg
#   inflating: AID/Viaduct/viaduct_72.jpg
#   inflating: AID/Viaduct/viaduct_73.jpg
#   inflating: AID/Viaduct/viaduct_74.jpg
#   inflating: AID/Viaduct/viaduct_75.jpg
#   inflating: AID/Viaduct/viaduct_76.jpg
#   inflating: AID/Viaduct/viaduct_77.jpg
#   inflating: AID/Viaduct/viaduct_78.jpg
#   inflating: AID/Viaduct/viaduct_79.jpg
#   inflating: AID/Viaduct/viaduct_8.jpg
#   inflating: AID/Viaduct/viaduct_80.jpg
#   inflating: AID/Viaduct/viaduct_81.jpg
#   inflating: AID/Viaduct/viaduct_82.jpg
#   inflating: AID/Viaduct/viaduct_83.jpg
#   inflating: AID/Viaduct/viaduct_84.jpg
#   inflating: AID/Viaduct/viaduct_85.jpg
#   inflating: AID/Viaduct/viaduct_86.jpg
#   inflating: AID/Viaduct/viaduct_87.jpg
#   inflating: AID/Viaduct/viaduct_88.jpg
#   inflating: AID/Viaduct/viaduct_89.jpg
#   inflating: AID/Viaduct/viaduct_9.jpg
#   inflating: AID/Viaduct/viaduct_90.jpg
#   inflating: AID/Viaduct/viaduct_91.jpg
#   inflating: AID/Viaduct/viaduct_92.jpg
#   inflating: AID/Viaduct/viaduct_93.jpg
#   inflating: AID/Viaduct/viaduct_94.jpg
#   inflating: AID/Viaduct/viaduct_95.jpg
#   inflating: AID/Viaduct/viaduct_96.jpg
#   inflating: AID/Viaduct/viaduct_97.jpg
#   inflating: AID/Viaduct/viaduct_98.jpg
#   inflating: AID/Viaduct/viaduct_99.jpg

# %% [markdown]
# ## <font color='darkorange'>Preprocessing images</font>

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders # import splitfolders to automate the folder test/train splitting
input_folder = "/content/AID"
output = "/content/split_data" 
splitfolders.ratio(input_folder, output=output, seed=42, ratio=(.8, .1, .1))
# Out:
# Copying files: 10000 files [00:22, 443.30 files/s]

# %%
from tensorflow.keras.utils import image_dataset_from_directory
import pathlib, os

#Set the path to the images
new_base_dir = pathlib.Path("/content/split_data")

# %%
#Training data
train_dataset = image_dataset_from_directory(
            new_base_dir / "train",
            image_size=(180, 180),
            batch_size=40)
# Out:
# Found 8000 files belonging to 30 classes.

# %%
#validation data
validation_dataset = image_dataset_from_directory(
            new_base_dir / "val",
            image_size=(180, 180),
            batch_size=40)
# Out:
# Found 1000 files belonging to 30 classes.

# %%
#test data
test_dataset = image_dataset_from_directory(
            new_base_dir / "test",
            image_size=(180, 180),
            batch_size=1)
# Out:
# Found 1000 files belonging to 30 classes.

# %%
for data_batch, labels_batch in train_dataset:
  print("data batch shape:", data_batch.shape)
  print("labels batch shape:", labels_batch.shape)
  break
# Out:
# data batch shape: (40, 180, 180, 3)
# labels batch shape: (40,)

# %% [markdown]
# ## <font color='darkorange'>Build a standard CNN</font>

# %%
#define all the layers of the model
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Flatten()(inputs)
x = layers.Rescaling(1.0/255)(x)
x = layers.Dense(100, activation='relu')(x)
x = layers.Dense(50, activation='relu')(x)
#x = layers.Dense(20, activation='relu')(x)
outputs = layers.Dense(30, activation="softmax")(x)

#build the model
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
#set the early stopping and model saving
callbacks = [
    keras.callbacks.ModelCheckpoint(
    filepath="Dense_NN.keras",
    save_best_only=True,
    monitor="val_loss"),
    
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=5)
]

#fit the model
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 200/200 [==============================] - 58s 281ms/step - loss: 7.6839 - accuracy: 0.0416 - val_loss: 3.3964 - val_accuracy: 0.0420
# Epoch 2/30
# 200/200 [==============================] - 63s 304ms/step - loss: 3.4699 - accuracy: 0.0420 - val_loss: 3.3923 - val_accuracy: 0.0420
# Epoch 3/30
# 200/200 [==============================] - 65s 317ms/step - loss: 3.4516 - accuracy: 0.0420 - val_loss: 3.3897 - val_accuracy: 0.0420
# Epoch 4/30
# 200/200 [==============================] - 58s 285ms/step - loss: 3.4574 - accuracy: 0.0419 - val_loss: 3.3881 - val_accuracy: 0.0420
# Epoch 5/30
# 200/200 [==============================] - 59s 291ms/step - loss: 3.4310 - accuracy: 0.0422 - val_loss: 3.3873 - val_accuracy: 0.0420
# Epoch 6/30
# 200/200 [==============================] - 59s 289ms/step - loss: 3.3875 - accuracy: 0.0420 - val_loss: 3.3868 - val_accuracy: 0.0420

# %%
#make the training and validation loss plot
plt.plot(history.history['loss'], label="Training loss")
plt.plot(history.history['val_loss'], label="Validation loss")
plt.legend()

# %%
#make the training and validation accuracy plot
plt.plot(history.history['accuracy'], label="Training accuracy")
plt.plot(history.history['val_accuracy'], label="Validation accuracy")
plt.legend()

# %%
round( max(history.history["val_accuracy"]), 3)
# Out:
# 0.042

# %% [markdown]
# # Build Convolutional NN

# %%
data_augmentation = keras.Sequential(
            [
               layers.RandomFlip("horizontal"),
               layers.RandomRotation(0.1),
               layers.RandomZoom(0.1),
] )

# %% [markdown]
# Let's add this step to our model and see if it helps performance!

# %%
#define all the layers of the model
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs) #added data augmentation
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
#x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)       #with both these layers included the NN is too deep and gets caught at val_accuraccy=0.042 
#x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(30, activation="softmax")(x)

#build the model
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# Let's fit this new model

# %%
#set the early stopping and model saving
callbacks = [
    keras.callbacks.ModelCheckpoint(
    filepath="Convnet_max_tools.keras",
    save_best_only=True,
    monitor="val_loss"),
    
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=5)
]

#fit the model
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 200/200 [==============================] - 67s 257ms/step - loss: 2.8254 - accuracy: 0.1954 - val_loss: 2.6651 - val_accuracy: 0.3100
# Epoch 2/30
# 200/200 [==============================] - 49s 240ms/step - loss: 1.9787 - accuracy: 0.4089 - val_loss: 1.6489 - val_accuracy: 0.5010
# Epoch 3/30
# 200/200 [==============================] - 46s 220ms/step - loss: 1.6638 - accuracy: 0.5010 - val_loss: 1.8288 - val_accuracy: 0.4580
# Epoch 4/30
# 200/200 [==============================] - 46s 225ms/step - loss: 1.4585 - accuracy: 0.5570 - val_loss: 1.8347 - val_accuracy: 0.5360
# Epoch 5/30
# 200/200 [==============================] - 54s 265ms/step - loss: 1.3347 - accuracy: 0.5985 - val_loss: 1.4920 - val_accuracy: 0.5750
# Epoch 6/30
# 200/200 [==============================] - 46s 221ms/step - loss: 1.2062 - accuracy: 0.6399 - val_loss: 1.1246 - val_accuracy: 0.6590
# Epoch 7/30
# 200/200 [==============================] - 49s 240ms/step - loss: 1.0901 - accuracy: 0.6668 - val_loss: 0.9803 - val_accuracy: 0.6890
# Epoch 8/30
# 200/200 [==============================] - 45s 215ms/step - loss: 1.0382 - accuracy: 0.6881 - val_loss: 0.9938 - val_accuracy: 0.6780
# Epoch 9/30
# 200/200 [==============================] - 46s 222ms/step - loss: 0.9738 - accuracy: 0.7069 - val_loss: 0.8812 - val_accuracy: 0.7250
# Epoch 10/30
# 200/200 [==============================] - 44s 216ms/step - loss: 0.9237 - accuracy: 0.7180 - val_loss: 1.2661 - val_accuracy: 0.6260
# Epoch 11/30
# 200/200 [==============================] - 46s 223ms/step - loss: 0.8635 - accuracy: 0.7311 - val_loss: 0.8397 - val_accuracy: 0.7420
# Epoch 12/30
# 200/200 [==============================] - 45s 216ms/step - loss: 0.8359 - accuracy: 0.7436 - val_loss: 1.1074 - val_accuracy: 0.6760
# Epoch 13/30
# 200/200 [==============================] - 46s 222ms/step - loss: 0.7997 - accuracy: 0.7571 - val_loss: 1.1311 - val_accuracy: 0.6810
# Epoch 14/30
# 200/200 [==============================] - 45s 219ms/step - loss: 0.7654 - accuracy: 0.7645 - val_loss: 1.0118 - val_accuracy: 0.7080
# Epoch 15/30
# 200/200 [==============================] - 44s 214ms/step - loss: 0.7422 - accuracy: 0.7753 - val_loss: 0.9032 - val_accuracy: 0.7290
# Epoch 16/30
# 200/200 [==============================] - 45s 221ms/step - loss: 0.7143 - accuracy: 0.7830 - val_loss: 0.9261 - val_accuracy: 0.7120

# %% [markdown]
# Let's see how the model fit.

# %%
#make the training and validation loss plot
plt.plot(history.history['loss'], label="Training loss")
plt.plot(history.history['val_loss'], label="Validation loss")
plt.legend()

# %%
#make the training and validation accuracy plot
plt.plot(history.history['accuracy'], label="Training accuracy")
plt.plot(history.history['val_accuracy'], label="Validation accuracy")
plt.legend()

# %%
round( max(history.history["val_accuracy"]), 3)
# Out:
# 0.742

# %% [markdown]
# ## <font color='lightblue'>Pretrained Model</font>

# %%
#load a pretreined model
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
print(conv_base.summary() )
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Set all the weights to non-trainable
conv_base.trainable = False

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x) #this prepairs the data for vgg16
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(30, activation="softmax")(x)
model = keras.Model(inputs, outputs)

# %%
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  tf.__operators__.getitem (S  (None, 180, 180, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 180, 180, 3)      0
#
#  vgg16 (Functional)          (None, None, None, 512)   14714688
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_1 (Dense)             (None, 256)               3277056
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 30)                7710
#
# =================================================================
# Total params: 17,999,454
# Trainable params: 3,284,766
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_vgg16.keras",
        save_best_only=True,
        monitor="val_loss"),
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=5)
]

# %%
history = model.fit(
            train_dataset,
            epochs=50,
            validation_data=validation_dataset,
            callbacks=callbacks)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 54s 240ms/step - loss: 24.0240 - accuracy: 0.6384 - val_loss: 15.3781 - val_accuracy: 0.8030
# Epoch 2/50
# 200/200 [==============================] - 48s 234ms/step - loss: 14.8056 - accuracy: 0.7778 - val_loss: 16.2275 - val_accuracy: 0.8300
# Epoch 3/50
# 200/200 [==============================] - 48s 233ms/step - loss: 12.6030 - accuracy: 0.8185 - val_loss: 12.4591 - val_accuracy: 0.8650
# Epoch 4/50
# 200/200 [==============================] - 49s 233ms/step - loss: 11.3340 - accuracy: 0.8426 - val_loss: 16.6035 - val_accuracy: 0.8440
# Epoch 5/50
# 200/200 [==============================] - 50s 241ms/step - loss: 9.9866 - accuracy: 0.8583 - val_loss: 12.1053 - val_accuracy: 0.8440
# Epoch 6/50
# 200/200 [==============================] - 48s 235ms/step - loss: 9.3348 - accuracy: 0.8649 - val_loss: 11.9100 - val_accuracy: 0.8750
# Epoch 7/50
# 200/200 [==============================] - 50s 243ms/step - loss: 8.6880 - accuracy: 0.8795 - val_loss: 11.3345 - val_accuracy: 0.8860
# Epoch 8/50
# 200/200 [==============================] - 49s 239ms/step - loss: 7.4343 - accuracy: 0.8881 - val_loss: 12.6859 - val_accuracy: 0.8730
# Epoch 9/50
# 200/200 [==============================] - 48s 236ms/step - loss: 7.4552 - accuracy: 0.8869 - val_loss: 10.4400 - val_accuracy: 0.8880
# Epoch 10/50
# 200/200 [==============================] - 49s 237ms/step - loss: 6.5760 - accuracy: 0.8996 - val_loss: 13.5512 - val_accuracy: 0.8670
# Epoch 11/50
# 200/200 [==============================] - 47s 228ms/step - loss: 7.2059 - accuracy: 0.8978 - val_loss: 13.6556 - val_accuracy: 0.8710
# Epoch 12/50
# 200/200 [==============================] - 47s 229ms/step - loss: 6.7806 - accuracy: 0.9016 - val_loss: 11.9888 - val_accuracy: 0.8920
# Epoch 13/50
# 200/200 [==============================] - 48s 232ms/step - loss: 6.4021 - accuracy: 0.9071 - val_loss: 13.3544 - val_accuracy: 0.8740
# Epoch 14/50
# 200/200 [==============================] - 48s 236ms/step - loss: 5.9951 - accuracy: 0.9059 - val_loss: 14.0054 - val_accuracy: 0.8860
# Epoch 15/50
# 200/200 [==============================] - 47s 230ms/step - loss: 5.9618 - accuracy: 0.9129 - val_loss: 12.8304 - val_accuracy: 0.8790
# Epoch 16/50
# 200/200 [==============================] - 48s 227ms/step - loss: 5.4144 - accuracy: 0.9119 - val_loss: 12.5990 - val_accuracy: 0.8770
# Epoch 17/50
# 200/200 [==============================] - 48s 234ms/step - loss: 5.6673 - accuracy: 0.9165 - val_loss: 12.4253 - val_accuracy: 0.8930
# Epoch 18/50
# 200/200 [==============================] - 48s 235ms/step - loss: 4.8006 - accuracy: 0.9194 - val_loss: 13.9217 - val_accuracy: 0.8800
# Epoch 19/50
# 200/200 [==============================] - 46s 223ms/step - loss: 5.2970 - accuracy: 0.9172 - val_loss: 12.3486 - val_accuracy: 0.8920
# Epoch 20/50
# 200/200 [==============================] - 46s 223ms/step - loss: 4.6440 - accuracy: 0.9245 - val_loss: 14.1483 - val_accuracy: 0.8820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-8459cf3c95ce> in <module>()
#       3             epochs=50,
#       4             validation_data=validation_dataset,
# ----> 5             callbacks=callbacks)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1371       logs = None
#    1372       for epoch, iterator in data_handler.enumerate_epochs():
# -> 1373         self.reset_metrics()
#    1374         callbacks.on_epoch_begin(epoch)
#    1375         with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %%
#make the training and validation loss plot
plt.plot(history.history['loss'], label="Training loss")
plt.plot(history.history['val_loss'], label="Validation loss")
plt.legend()

# %%
#make the training and validation accuracy plot
plt.plot(history.history['accuracy'], label="Training accuracy")
plt.plot(history.history['val_accuracy'], label="Validation accuracy")
plt.legend()

# %%
round( max(history.history["val_accuracy"]), 3)
# Out:
# 0.742

# %% [markdown]
# ## <font color='lightblue'>Test and Explore our Best Model</font>

# %%
model = keras.models.load_model("feature_extraction_with_vgg16.keras")

model.evaluate(test_dataset)
# Out:
# 1000/1000 [==============================] - 16s 15ms/step - loss: 14.8300 - accuracy: 0.8660
# [14.830024719238281, 0.8659999966621399]

# %% [markdown]
# Without full training of our VGG model we still achieve 86.5% accuracy.

# %%
img_path = keras.utils.get_file(
    fname="baseballfield_10.jpg",
    origin="/content/split_data/val/BaseballField/baseballfield_10.jpg")
# Out:
# Downloading data from /content/split_data/val/BaseballField/baseballfield_10.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-08b8f990e691> in <module>()
#       1 img_path = keras.utils.get_file(
#       2     fname="baseballfield_10.jpg",
# ----> 3     origin="/content/split_data/val/BaseballField/baseballfield_10.jpg")
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     275     try:
#     276       try:
# --> 277         urlretrieve(origin, fpath, dl_progress)
#     278       except urllib.error.HTTPError as e:
#     279         raise Exception(error_msg.format(origin, e.code, e.msg))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py in urlretrieve(url, filename, reporthook, data)
#      80           break
#      81
# ---> 82     response = urlopen(url, data)
#      83     with open(filename, 'wb') as fd:
#      84       for chunk in chunk_read(response, reporthook=reporthook):
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     508         # accept a URL or a Request object
#     509         if isinstance(fullurl, str):
# --> 510             req = Request(fullurl, data)
#     511         else:
#     512             req = fullurl
#
# /usr/lib/python3.7/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     326                  origin_req_host=None, unverifiable=False,
#     327                  method=None):
# --> 328         self.full_url = url
#     329         self.headers = {}
#     330         self.unredirected_hdrs = {}
#
# /usr/lib/python3.7/urllib/request.py in full_url(self, url)
#     352         self._full_url = unwrap(url)
#     353         self._full_url, self.fragment = splittag(self._full_url)
# --> 354         self._parse()
#     355
#     356     @full_url.deleter
#
# /usr/lib/python3.7/urllib/request.py in _parse(self)
#     381         self.type, rest = splittype(self._full_url)
#     382         if self.type is None:
# --> 383             raise ValueError("unknown url type: %r" % self.full_url)
#     384         self.host, self.selector = splithost(rest)
#     385         if self.host:
#
# ValueError: unknown url type: '/content/split_data/val/BaseballField/baseballfield_10.jpg'

# %%
#make the image fit into the model
def get_img_array(img_path, target_size): 
  img = keras.utils.load_img(img_path, target_size=target_size)
  array = keras.utils.img_to_array(img) 
  array = np.expand_dims(array, axis=0) 
  return array

img_tensor = get_img_array(img_path, target_size=(180, 180))

import matplotlib.pyplot as plt 

plt.axis("off")
plt.imshow(img_tensor[0].astype("uint8")) 
plt.show()

# %%
model_viz.layers

# %%
depth = 11

# %%
activation_model = keras.Model(inputs=model_viz.inputs, outputs=model_viz.layers[depth].output)

# %%
activations = activation_model.predict(img_tensor)

# %%
first_layer_activation = activations[0]

# %%
print(first_layer_activation.shape)

# %%
import matplotlib.pyplot as plt 
plt.matshow(first_layer_activation[:, :, 12], cmap="viridis")

# %% [markdown]
# Can we see some of the edge detection?

# %%
train_ds = validation_dataset.unbatch()
images = np.asarray(list(validation_dataset.map(lambda x, y: x)))
labels = np.asarray(list(validation_dataset.map(lambda x, y: y)))

# %%
# !pip install shap -U
import shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (569 kB)
#      |████████████████████████████████| 569 kB 32.4 MB/s
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.56.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.39.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
# Build explainer to help explain predictions of the model
explainer = shap.GradientExplainer(model_viz, images[1,:,:,:,:])

# compute shap values
shap_values = explainer.shap_values(images[1,:,:,:,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-be5448752f93> in <module>()
#       1 # Build explainer to help explain predictions of the model
# ----> 2 explainer = shap.GradientExplainer(model_viz, images[1,:,:,:,:])
#       3
#       4 # compute shap values
#       5 shap_values = explainer.shap_values(images[1,:,:,:,:])
#
# NameError: name 'model_viz' is not defined

# %%
# plot SHAP values
shap.image_plot(shap_values,images[1,20:21,:,:,:]/255)

# %% [markdown]
# ## <font color='lightblue'>Discussion</font>
#
# ###*Compare* the results of the dense and convolutional approach to model building.
#
# > Q7. Does one model outperform the other? (Marks: 1)

# %% [markdown]
# The dense model was only able to return an accuracy of 4%. With 30 classes random selection would result in 3%. As the validation accuracy didn't change with epoch as trained it is assumed the model is failing to train properly. The issue is likely a result of the flatten layer not passing the data in a shape the model expects.
#
# The convolutional model, without VGG trasnfered learning, had a maximum validation accuracy score of 80%. This model utilized data augmentation, as well as a dropout layer. The AID researchers reported an overall acuraccy of 89.64% using VGG-VD-16, when training on 50% of the dataset.

# %% [markdown]
# ###Justify your choice of model architecture for the convolutional neural network (Marks:4)
#
# > **Q3: Why did you choose the types of layers you did?**
#
# A data augmentation layer was added at the beginning of the neural net in hopes of avoiding the model learning unwanted patterns. By scaling and rotating random images we can introduce stochasticity. This helps ensure the model only learns patterns that are caused by image artifacts. After the data augmentation layer we scale all our RGB values to be between 0 and 1. This reduces computational load and improves model performance. A series of Conv2D and MaxPooling layers were then added to create an expanding hypothesis space. The separableConv2D layer was originally implemented but reduced acuraccy by ~4%. This lets us infer that some correlation between colour layers is useful for predicting landscape and scenery.
#
# One attempt was made to create a deeper net, which used 512 filter Conv2D layer. This created issues with back propagation causing the model to not be able to train over 4%. This depth may be possible with added residual connections, but no solution could be found that warranted the added complexity.
#
# > **Q4: Why did you choose the size of layers you did?**
#
# Early in the architecture we want our model to learn fewer filters, increasing in number as we go deep into the model. This helps expand the patterns the model identifies, starting with small edges and curve and ending with defined shapes.
#
# > **Q5: Why did you organize the layers the way you did?**
#
# Each layer has a growing number of filters to learn higher level patterns. After each Conv2D layer a MaxPooling layer is used to reduce the spatial dimension of the output volume. Kernel size was set to 3, resulting in a 3x3 pixel filter for each layer.
#
#  With more computational power it would be of interest to run the images uncompressed, 600x600, and larger filters to see how results vary. The intuition behind this is that many of the buildings and natural features are large in respect to the 600x600 pixel image, thus requiring larger filters to be recognized. To do this the first layer would be set to a kernel size of 7, the second layer set to 5, and all following layers set to 3.
#
# > **Q6: Why did you choose the output layer size and activation function that you did?**
#
# As we are trying to predict the probability that an image falls into a certain classification "softmax" was chosen. We used 30 nodes at the output layer, one corresponding to each class.

# %% [markdown]
# ## <font color='lightblue'>Citations</font>
# AID: A Benchmark Dataset for Performance Evaluation of Aerial Scene Classification
# Gui-Song Xia1, Jingwen Hu1,2, Fan Hu1,2, Baoguang Shi3, Xiang Bai3, Yanfei Zhong1, Liangpei Zhang1
#
# 1. State Key Lab. LIESMARS, Wuhan University, Wuhan 430079, China
# 2. EIS, Wuhan University, Wuhan, 430079, China
# 3. EIC, Huazhong University of Science and Technology, Wuhan 430074, China.
#
# published on IEEE Trans. on Geoscience and Remote Sensing, Vol. 55, No.7, pp.3965 - 3981, 2017.
# https://captain-whu.github.io/AID/
